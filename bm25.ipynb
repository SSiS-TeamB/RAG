# %%
from rank_bm25 import BM25Okapi
from document import BaseDBLoader

# %%
## corpus 생성까지
loader = BaseDBLoader()

document = loader.load(is_regex=True, is_split=False)
# print(document)
corpus = loader.get_corpus()

# %%
v_list = list(corpus.values())
# for v in v_list:
print(v_list[0])
# Out:
# 어르신 국가예방접종 지원 사업
#
# 대상
#
# 65세 이상 어르신(1958년 12월 31일 이전 출생자)
#  주민등록상 출생연도 기준
#
# 내용
#
# 폐렴구균
#  폐렴구균 23가 다당 백신(PPSV23), 1회 지원
#
#  인플루엔자
#  인플루엔자 4가 백신(IIV), 매년 1회 지원          인플루엔자는 접종시기가 정해져 있는 계절사업임(매년 10월경)
#
# 방법
#
# 신분증을 지참하고 전국 지정의료기관 및 보건소 방문
#  지정의료기관 확인 예방접종도우미 누리집
#  접종기관 방문 전 접종가능 여부 확인 필수
#
# 문의
#
# 질병관리청 콜센터(1339)
#
# 질병관리청 예방접종관리과(04371983988399)
#
# 자주 하는 질문
#
# 인플루엔자 백신과 폐렴구균 백신은 동시접종이 가능한가요
#
# 일반적으로 인플루엔자 백신과 폐렴구균 백신은 동시접종이 가능하며, 동시접종을 하지 못한 경우 특별히 지켜야 할 접종간격은 없습니다. 다만, 의사 예진 후 피접종자의 건강 상태 등을 고려하여 접종 일정을 조정할 수는 있습니다.

# %%
corpus1 = [v_list[0]]
def tockenizer(sent):
    return sent.split(" ")
tockenized_corpus = [tockenizer(doc) for doc in corpus1]
bm25 = BM25Okapi(tockenized_corpus)

# %%
bm25.doc_len
# Out:
# [100]

# %%
bm25.doc_freqs
# Out:
# [{'어르신': 1,
#   '국가예방접종': 1,
#   '지원': 3,
#   '사업\n\n대상\n\n65세': 1,
#   '이상': 1,
#   '어르신(1958년': 1,
#   '12월': 1,
#   '31일': 1,
#   '이전': 1,
#   '출생자)\n': 1,
#   '주민등록상': 1,
#   '출생연도': 1,
#   '기준\n\n내용\n\n폐렴구균': 1,
#   '\n': 4,
#   '폐렴구균': 3,
#   '23가': 1,
#   '다당': 1,
#   '백신(PPSV23),': 1,
#   '1회': 2,
#   '인플루엔자': 3,
#   '4가': 1,
#   '백신(IIV),': 1,
#   '매년': 1,
#   '': 9,
#   '인플루엔자는': 1,
#   '접종시기가': 1,
#   '정해져': 1,
#   '있는': 1,
#   '계절사업임(매년': 1,
#   '10월경)\n\n방법\n\n신분증을': 1,
#   '지참하고': 1,
#   '전국': 1,
#   '지정의료기관': 2,
#   '및': 1,
#   '보건소': 1,
#   '방문\n': 1,
#   '확인': 2,
#   '예방접종도우미': 1,
#   '누리집\n': 1,
#   '접종기관': 1,
#   '방문': 1,
#   '전': 1,
#   '접종가능': 1,
#   '여부': 1,
#   '필수\n\n문의\n\n질병관리청': 1,
#   '콜센터(1339)\n\n질병관리청': 1,
#   '예방접종관리과(04371983988399)\n\n자주': 1,
#   '하는': 1,
#   '질문\n\n인플루엔자': 1,
#   '백신과': 2,
#   '백신은': 2,
#   '동시접종이': 2,
#   '가능한가요\n\n일반적으로': 1,
#   '가능하며,': 1,
#   '동시접종을': 1,
#   '하지': 1,
#   '못한': 1,
#   '경우': 1,
#   '특별히': 1,
#   '지켜야': 1,
#   '할': 1,
#   '접종간격은': 1,
#   '없습니다.': 1,
#   '다만,': 1,
#   '의사': 1,
#   '예진': 1,
#   '후': 1,
#   '피접종자의': 1,
#   '건강': 1,
#   '상태': 1,
#   '등을': 1,
#   '고려하여': 1,
#   '접종': 1,
#   '일정을': 1,
#   '조정할': 1,
#   '수는': 1,
#   '있습니다.': 1}]

# %%
bm25.idf
# Out:
# {'어르신': -0.2746530721670271,
#  '국가예방접종': -0.2746530721670271,
#  '지원': -0.2746530721670271,
#  '사업\n\n대상\n\n65세': -0.2746530721670271,
#  '이상': -0.2746530721670271,
#  '어르신(1958년': -0.2746530721670271,
#  '12월': -0.2746530721670271,
#  '31일': -0.2746530721670271,
#  '이전': -0.2746530721670271,
#  '출생자)\n': -0.2746530721670271,
#  '주민등록상': -0.2746530721670271,
#  '출생연도': -0.2746530721670271,
#  '기준\n\n내용\n\n폐렴구균': -0.2746530721670271,
#  '\n': -0.2746530721670271,
#  '폐렴구균': -0.2746530721670271,
#  '23가': -0.2746530721670271,
#  '다당': -0.2746530721670271,
#  '백신(PPSV23),': -0.2746530721670271,
#  '1회': -0.2746530721670271,
#  '인플루엔자': -0.2746530721670271,
#  '4가': -0.2746530721670271,
#  '백신(IIV),': -0.2746530721670271,
#  '매년': -0.2746530721670271,
#  '': -0.2746530721670271,
#  '인플루엔자는': -0.2746530721670271,
#  '접종시기가': -0.2746530721670271,
#  '정해져': -0.2746530721670271,
#  '있는': -0.2746530721670271,
#  '계절사업임(매년': -0.2746530721670271,
#  '10월경)\n\n방법\n\n신분증을': -0.2746530721670271,
#  '지참하고': -0.2746530721670271,
#  '전국': -0.2746530721670271,
#  '지정의료기관': -0.2746530721670271,
#  '및': -0.2746530721670271,
#  '보건소': -0.2746530721670271,
#  '방문\n': -0.2746530721670271,
#  '확인': -0.2746530721670271,
#  '예방접종도우미': -0.2746530721670271,
#  '누리집\n': -0.2746530721670271,
#  '접종기관': -0.2746530721670271,
#  '방문': -0.2746530721670271,
#  '전': -0.2746530721670271,
#  '접종가능': -0.2746530721670271,
#  '여부': -0.2746530721670271,
#  '필수\n\n문의\n\n질병관리청': -0.2746530721670271,
#  '콜센터(1339)\n\n질병관리청': -0.2746530721670271,
#  '예방접종관리과(04371983988399)\n\n자주': -0.2746530721670271,
#  '하는': -0.2746530721670271,
#  '질문\n\n인플루엔자': -0.2746530721670271,
#  '백신과': -0.2746530721670271,
#  '백신은': -0.2746530721670271,
#  '동시접종이': -0.2746530721670271,
#  '가능한가요\n\n일반적으로': -0.2746530721670271,
#  '가능하며,': -0.2746530721670271,
#  '동시접종을': -0.2746530721670271,
#  '하지': -0.2746530721670271,
#  '못한': -0.2746530721670271,
#  '경우': -0.2746530721670271,
#  '특별히': -0.2746530721670271,
#  '지켜야': -0.2746530721670271,
#  '할': -0.2746530721670271,
#  '접종간격은': -0.2746530721670271,
#  '없습니다.': -0.2746530721670271,
#  '다만,': -0.2746530721670271,
#  '의사': -0.2746530721670271,
#  '예진': -0.2746530721670271,
#  '후': -0.2746530721670271,
#  '피접종자의': -0.2746530721670271,
#  '건강': -0.2746530721670271,
#  '상태': -0.2746530721670271,
#  '등을': -0.2746530721670271,
#  '고려하여': -0.2746530721670271,
#  '접종': -0.2746530721670271,
#  '일정을': -0.2746530721670271,
#  '조정할': -0.2746530721670271,
#  '수는': -0.2746530721670271,
#  '있습니다.': -0.2746530721670271}

# %%
query = ""
tokenized_query = tokenizer(query)

doc_scores = bm25.get_scores(tokenized_query)
doc_scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jk/CODE/ssis_team/RAG-joonho/langchain/bm25.ipynb 셀 8 line 2
#       <a href='vscode-notebook-cell:/Users/jk/CODE/ssis_team/RAG-joonho/langchain/bm25.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> query = "도미노피자 신메뉴"
# ----> <a href='vscode-notebook-cell:/Users/jk/CODE/ssis_team/RAG-joonho/langchain/bm25.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> tokenized_query = tokenizer(query)
#       <a href='vscode-notebook-cell:/Users/jk/CODE/ssis_team/RAG-joonho/langchain/bm25.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> doc_scores = bm25.get_scores(tokenized_query)
#       <a href='vscode-notebook-cell:/Users/jk/CODE/ssis_team/RAG-joonho/langchain/bm25.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> doc_scores
#
# NameError: name 'tokenizer' is not defined
