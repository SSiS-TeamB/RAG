# %%
from rank_bm25 import BM25Okapi
from document import BaseDBLoader

# %%
## corpus 생성까지
loader = BaseDBLoader()

document = loader.load(is_regex=True, is_split=False)
# print(document)
corpus = loader.get_corpus()
# Out:
# /Users/jk/anaconda3/envs/ssis/lib/python3.10/site-packages/unstructured/documents/html.py:498: FutureWarning: The behavior of this method will change in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.
#   rows = body.findall("tr") if body else []

# %%
v_list = list(corpus.values())

corpus1 = []
for i in range(len(v_list)):
    corpus1.append(v_list[i])
def tockenizer(sent):
    return sent.split(" ")

tockenized_corpus = [tockenizer(doc) for doc in corpus1]
bm25 = BM25Okapi(tockenized_corpus)

# %%
bm25.doc_len
# Out:
# [100,
#  52,
#  46,
#  26,
#  7,
#  157,
#  111,
#  38,
#  198,
#  238,
#  163,
#  49,
#  47,
#  117,
#  125,
#  130,
#  92,
#  184,
#  115,
#  237,
#  53,
#  29,
#  164,
#  86,
#  216,
#  50,
#  42,
#  243,
#  100,
#  44,
#  53,
#  224,
#  47,
#  69,
#  131,
#  149,
#  186,
#  47,
#  55,
#  90,
#  142,
#  134,
#  80,
#  30,
#  52,
#  330,
#  79,
#  245,
#  286,
#  148,
#  46,
#  59,
#  111,
#  97,
#  145,
#  249,
#  101,
#  25,
#  133,
#  61,
#  63,
#  56,
#  228,
#  135,
#  184,
#  31,
#  31,
#  68,
#  113,
#  28,
#  127,
#  164,
#  188,
#  120,
#  125,
#  52,
#  40,
#  36,
#  61,
#  38,
#  45,
#  39,
#  76,
#  58,
#  184,
#  39,
#  312,
#  69,
#  67,
#  83,
#  116,
#  452,
#  50,
#  29,
#  307,
#  69,
#  559,
#  80,
#  28,
#  518,
#  112,
#  57,
#  490,
#  44,
#  36,
#  86,
#  241,
#  656,
#  19,
#  233,
#  137,
#  166,
#  43,
#  101,
#  512,
#  23,
#  31,
#  194,
#  60,
#  30,
#  329,
#  47,
#  36,
#  80,
#  43,
#  48,
#  145,
#  584,
#  113,
#  33,
#  38,
#  126,
#  389,
#  42,
#  97,
#  154,
#  191,
#  132,
#  82,
#  137,
#  25,
#  64,
#  83,
#  107,
#  43,
#  84,
#  114,
#  33,
#  58,
#  87,
#  35,
#  216,
#  170,
#  85,
#  20,
#  111,
#  45,
#  222,
#  42,
#  41,
#  70,
#  62,
#  70,
#  93,
#  77,
#  59,
#  56,
#  169,
#  22,
#  95,
#  60,
#  40,
#  63,
#  62,
#  38,
#  40,
#  45,
#  32,
#  67,
#  78,
#  79,
#  33,
#  24,
#  72,
#  214,
#  341,
#  149,
#  110,
#  89,
#  79,
#  43,
#  61,
#  217,
#  228,
#  47,
#  49,
#  92,
#  133,
#  85,
#  158,
#  66,
#  96,
#  57,
#  245,
#  49,
#  171,
#  153,
#  37,
#  30,
#  69,
#  175,
#  73,
#  44,
#  87,
#  173,
#  214,
#  234,
#  157,
#  91,
#  65,
#  61,
#  74,
#  155,
#  51,
#  202,
#  52,
#  89,
#  85,
#  38,
#  116,
#  54,
#  51,
#  81,
#  95,
#  83,
#  355,
#  56,
#  87,
#  192,
#  53,
#  61,
#  94,
#  78,
#  109,
#  33,
#  121,
#  109,
#  419,
#  38,
#  71,
#  35,
#  135,
#  177,
#  28,
#  44,
#  84,
#  25,
#  255,
#  141,
#  63,
#  41,
#  180,
#  56,
#  106,
#  119,
#  51,
#  98,
#  40,
#  31,
#  55,
#  158,
#  87,
#  33,
#  83,
#  212,
#  513,
#  67,
#  192,
#  146,
#  230,
#  249,
#  47,
#  150,
#  279,
#  64,
#  167,
#  95,
#  41,
#  197,
#  83,
#  65,
#  140,
#  67,
#  84,
#  58,
#  43,
#  61,
#  36,
#  36,
#  147,
#  79,
#  71,
#  17,
#  99,
#  121,
#  119,
#  38,
#  174,
#  15,
#  55,
#  66,
#  28,
#  56,
#  105,
#  136,
#  45,
#  85,
#  92,
#  26,
#  73,
#  19,
#  48,
#  144,
#  32,
#  80,
#  58,
#  39,
#  208,
#  124,
#  100,
#  64,
#  42,
#  81,
#  97,
#  29,
#  28,
#  87,
#  152,
#  142,
#  170,
#  60,
#  51,
#  205,
#  56,
#  29,
#  28,
#  21,
#  46,
#  257,
#  107,
#  146,
#  233,
#  123,
#  58,
#  70,
#  114,
#  37,
#  29,
#  18,
#  50,
#  76,
#  24,
#  26,
#  183,
#  70,
#  221,
#  107,
#  230,
#  108,
#  193,
#  405,
#  54,
#  43,
#  149,
#  92,
#  75,
#  106,
#  28,
#  51,
#  30,
#  22,
#  126,
#  31,
#  42,
#  74,
#  94,
#  45,
#  49,
#  27,
#  67,
#  35,
#  37,
#  80,
#  150,
#  247,
#  39,
#  87,
#  88,
#  69,
#  58,
#  95,
#  27,
#  31,
#  96,
#  64,
#  34,
#  57,
#  111,
#  38,
#  196,
#  146,
#  83,
#  246,
#  43,
#  36,
#  131,
#  26,
#  51,
#  23,
#  31,
#  49,
#  38,
#  28,
#  100,
#  29,
#  85,
#  55,
#  133,
#  106,
#  181,
#  59,
#  39,
#  33,
#  38,
#  44,
#  120,
#  49,
#  59,
#  57,
#  17,
#  143,
#  46,
#  27,
#  27,
#  139,
#  463,
#  477,
#  49,
#  59,
#  19,
#  13,
#  62,
#  131,
#  54,
#  37,
#  106,
#  141,
#  177,
#  55,
#  13,
#  178,
#  126,
#  90,
#  69]

# %%
bm25.doc_freqs
# Out:
# [{'어르신': 1,
#   '국가예방접종': 1,
#   '지원': 3,
#   '사업\n\n대상\n\n65세': 1,
#   '이상': 1,
#   '어르신(1958년': 1,
#   '12월': 1,
#   '31일': 1,
#   '이전': 1,
#   '출생자)\n': 1,
#   '주민등록상': 1,
#   '출생연도': 1,
#   '기준\n\n내용\n\n폐렴구균': 1,
#   '\n': 4,
#   '폐렴구균': 3,
#   '23가': 1,
#   '다당': 1,
#   '백신(PPSV23),': 1,
#   '1회': 2,
#   '인플루엔자': 3,
#   '4가': 1,
#   '백신(IIV),': 1,
#   '매년': 1,
#   '': 9,
#   '인플루엔자는': 1,
#   '접종시기가': 1,
#   '정해져': 1,
#   '있는': 1,
#   '계절사업임(매년': 1,
#   '10월경)\n\n방법\n\n신분증을': 1,
#   '지참하고': 1,
#   '전국': 1,
#   '지정의료기관': 2,
#   '및': 1,
#   '보건소': 1,
#   '방문\n': 1,
#   '확인': 2,
#   '예방접종도우미': 1,
#   '누리집\n': 1,
#   '접종기관': 1,
#   '방문': 1,
#   '전': 1,
#   '접종가능': 1,
#   '여부': 1,
#   '필수\n\n문의\n\n질병관리청': 1,
#   '콜센터(1339)\n\n질병관리청': 1,
#   '예방접종관리과(04371983988399)\n\n자주': 1,
#   '하는': 1,
#   '질문\n\n인플루엔자': 1,
#   '백신과': 2,
#   '백신은': 2,
#   '동시접종이': 2,
#   '가능한가요\n\n일반적으로': 1,
#   '가능하며,': 1,
#   '동시접종을': 1,
#   '하지': 1,
#   '못한': 1,
#   '경우': 1,
#   '특별히': 1,
#   '지켜야': 1,
#   '할': 1,
#   '접종간격은': 1,
#   '없습니다.': 1,
#   '다만,': 1,
#   '의사': 1,
#   '예진': 1,
#   '후': 1,
#   '피접종자의': 1,
#   '건강': 1,
#   '상태': 1,
#   '등을': 1,
#   '고려하여': 1,
#   '접종': 1,
#   '일정을': 1,
#   '조정할': 1,
#   '수는': 1,
#   '있습니다.': 1},
#  {'노인': 1,
#   '무릎': 2,
#   '인공관절': 2,
#   '수술': 1,
#   '지원\n\n대상\n\n만': 1,
#   '60세': 1,
#   '이상': 1,
#   '기초생활수급자,': 1,
#   '차상위계층,': 1,
#   '한부모가족': 1,
#   '중': 1,
#   '무릎인공관절': 2,
#   '수술이': 1,
#   '필요한': 1,
#   '어르신\n\n': 1,
#   '건강보험급여': 1,
#   '치환술(무릎관절)': 1,
#   '인정': 1,
#   '기준에': 1,
#   '준하는': 1,
#   '질환자\n\n내용\n\n검사비,': 1,
#   '진료비': 2,
#   '및': 1,
#   '수술비': 1,
#   '본인부담금(한쪽': 1,
#   '기준': 1,
#   '120만': 1,
#   '원)': 1,
#   '지원\n\n': 1,
#   '지원': 2,
#   '제외': 1,
#   '수술과': 1,
#   '관련': 1,
#   '없는': 1,
#   '검사비·치료비': 1,
#   '등,': 1,
#   '간병비·상급병실료': 1,
#   '등': 1,
#   '비급여,': 1,
#   '결정': 1,
#   '전에': 1,
#   '발생한': 1,
#   '등\n\n방법\n\n해당': 1,
#   '지역': 1,
#   '보건소에': 1,
#   '신청\n\n문의\n\n노인의료나눔재단(027116599,': 1,
#   'www.ok6595.or.kr)': 1},
#  {'은퇴금융': 2,
#   '아카데미\n\n대상': 1,
#   '은퇴준비에': 1,
#   '필요한': 2,
#   '경제금융지식': 1,
#   '및': 1,
#   '은퇴생활정보': 1,
#   '교육이': 1,
#   '사람\n\n내용': 1,
#   '\n': 3,
#   '자산관리,': 1,
#   '은퇴금융상품,': 1,
#   '신용·부채관리': 1,
#   '등': 2,
#   '금융지식과': 1,
#   '각종': 1,
#   '생활정보': 1,
#   '강좌': 1,
#   '무료': 1,
#   '제공\n\n방법': 1,
#   '개최': 1,
#   '시': 1,
#   '한국주택금융공사': 1,
#   '누리집에서': 1,
#   '수강': 1,
#   '지역과': 1,
#   '일정을': 1,
#   '안내\n\n문의': 1,
#   '한국주택금융공사(16888114,': 1,
#   'www.hf.go.kr)\n\n알려드립니다\n\n온라인으로': 1,
#   '상시': 1,
#   '교육': 1,
#   '수강이': 1,
#   '가능합니다.\n\n수강방법': 1,
#   '유튜브': 1,
#   '한국주택금융공사HF': 1,
#   '채널\n\n교육과정': 1,
#   '노후준비': 1,
#   '전략,': 1,
#   '재무설계,': 1,
#   '세금특강': 1},
#  {'노인복지관,': 1,
#   '경로당': 3,
#   '이용\n\n대상': 1,
#   '어르신\n\n내용': 1,
#   '\n동네': 1,
#   '노인복지관과': 1,
#   '내에': 1,
#   '다양한': 1,
#   '문화·교육': 1,
#   '프로그램을': 1,
#   '운영,': 1,
#   '어르신들의': 1,
#   '사회참여와': 1,
#   '문화': 1,
#   '향유를': 1,
#   '지원\n\n방법': 1,
#   '\n별도': 1,
#   '신청': 1,
#   '없이': 1,
#   '이용\n\n문의': 1,
#   '\n거주지': 1,
#   '인근': 1,
#   '복지관': 1,
#   '및': 1},
#  {'디지털배움터\n\n디지털배움터.kr)을': 1,
#   '통한': 1,
#   '온라인': 1,
#   '신청': 1,
#   '또는': 1,
#   '전화(18000096)': 1,
#   '신청\n\n디지털배움터.kr)': 1},
#  {'노후준비서비스\n\n대상': 1,
#   '국민연금': 1,
#   '가입대상': 1,
#   '및': 4,
#   '수급권자를': 1,
#   '포함한': 1,
#   '전': 1,
#   '국민\n\n내용': 1,
#   '노후준비를': 1,
#   '위한': 2,
#   '재무·건강·여가·대인관계': 1,
#   '등': 1,
#   '분야별': 1,
#   '진단,': 1,
#   '상담,': 1,
#   '교육,': 1,
#   '관계기관': 3,
#   '연계': 3,
#   '사후관리': 2,
#   '서비스': 3,
#   '제공\n\n진단': 1,
#   '': 3,
#   '상담': 5,
#   '교육': 2,
#   '또는': 2,
#   '사후관리\n\n진단': 1,
#   '\n': 13,
#   '재무,': 2,
#   '건강,': 2,
#   '여가,': 2,
#   '대인관계': 2,
#   '분야의': 1,
#   '표준지표로': 1,
#   '구성된': 1,
#   '종합진단지': 1,
#   '작성을': 1,
#   '통해': 2,
#   '노후준비': 3,
#   '상태를': 1,
#   '진단': 1,
#   '진단을': 1,
#   '파악된': 1,
#   '취약점을': 1,
#   '보완하기': 1,
#   '영역별': 1,
#   '실천': 1,
#   '과제': 1,
#   '방법': 1,
#   '등에': 1,
#   '대한': 1,
#   '공단': 1,
#   '소속': 1,
#   '전문': 1,
#   '강사들이': 1,
#   '제공하는': 1,
#   '영역': 1,
#   '맞춤형': 1,
#   '강의': 1,
#   '타': 1,
#   '기관의': 1,
#   '관련': 1,
#   '서비스를': 3,
#   '이용하거나': 1,
#   '심층상담이': 1,
#   '필요한': 1,
#   '경우': 1,
#   '해당': 1,
#   '기관으로': 1,
#   '연계하는': 1,
#   'OneStop': 1,
#   '상담시': 1,
#   '설정한': 1,
#   '과제의': 1,
#   '준수': 1,
#   '여부를': 1,
#   '주기적으로': 1,
#   '점검하고': 1,
#   '희망시': 1,
#   '추가': 1,
#   '정보': 1,
#   '제공\n\n방법': 1,
#   '국민연금공단': 3,
#   '20개': 1,
#   '거점지사': 1,
#   '방문': 1,
#   '온라인': 1,
#   '신청\n\n문의\n': 1,
#   '콜센터(1355)\n': 1,
#   'NPS중앙노후준비지원센터(csa.nps.or.kr)\n\n알려드립니다\n\n기존에는': 1,
#   '국민연금공단에서만': 1,
#   '노후준비서비스를': 1,
#   '이용하실': 2,
#   '수': 2,
#   '있었으나,': 1,
#   '2022년': 1,
#   '6월부터': 1,
#   '국민연금공단과': 1,
#   '지자체가': 1,
#   '협력하여': 1,
#   '더': 1,
#   '편리하게': 1,
#   '있도록': 1,
#   '저변이': 1,
#   '확대되었습니다.\n\n': 1,
#   '국민연금공단은': 1,
#   'CSA(노후준비컨설턴트)': 1,
#   '등의': 1,
#   '자격을': 1,
#   '보유한': 1,
#   '전문인력이': 1,
#   '최상의': 1,
#   '제공하고': 1,
#   '있습니다.': 1},
#  {'치매검진': 1,
#   '지원\n\n대상\n': 1,
#   '선별검사': 3,
#   '만': 2,
#   '60세': 3,
#   '이상': 1,
#   '어르신(만': 1,
#   '미만으로': 1,
#   '인지능력이': 1,
#   '현저히': 1,
#   '저하되는': 1,
#   '조기검진이': 1,
#   '필요하다고': 1,
#   '판단되는': 1,
#   '경우': 1,
#   '포함)\n': 1,
#   '진단·감별검사': 2,
#   '이상으로': 1,
#   '소득이': 1,
#   '기준': 2,
#   '중위소득': 1,
#   '120%(4인': 1,
#   '월': 1,
#   '648만': 1,
#   '2,000원)': 1,
#   '이하인': 1,
#   '어르신\n\n내용\n': 1,
#   '전국': 2,
#   '보건소에서': 2,
#   '치매': 2,
#   '및': 2,
#   '진단검사': 2,
#   '무료': 1,
#   '실시\n': 1,
#   '결과': 1,
#   '정밀검사': 1,
#   '필요': 1,
#   '시': 1,
#   '600여': 1,
#   '개소': 1,
#   '협약병원에서': 3,
#   '추가': 1,
#   '실시': 2,
#   '검사비': 2,
#   '일부': 1,
#   '지원\n\n선별검사': 1,
#   '\n': 10,
#   '선별을': 1,
#   '위한': 1,
#   '간단한': 1,
#   '인지선별검사': 1,
#   '(CIST)': 1,
#   '무료검사': 1,
#   '전문의': 1,
#   '진찰,': 1,
#   '치매척도검사,': 1,
#   '치매신경인지검사,': 1,
#   '일상생활척도검사': 1,
#   '등': 2,
#   '실시한': 2,
#   '검사비(15만': 1,
#   '원': 2,
#   '한도': 2,
#   '내)': 2,
#   '지원': 1,
#   '감별검사': 1,
#   '혈액검사,': 1,
#   '간기능검사,': 1,
#   '신장기능검사,': 1,
#   '뇌영상촬영': 1,
#   '(병원급': 1,
#   '8만': 1,
#   '원,': 1,
#   '상급종합병원': 1,
#   '11만': 1,
#   '지원\n\n방법\n': 1,
#   '보건소': 1,
#   '치매안심센터에': 1,
#   '신청\n\n문의\n': 1,
#   '보건복지상담센터(129)\n': 1,
#   '치매상담콜센터(18999988)': 1},
#  {'치매치료': 1,
#   '관리비': 1,
#   '지원사업\n\n대상': 1,
#   '치매치료제를': 1,
#   '복용': 1,
#   '중인': 1,
#   '만': 1,
#   '60세': 1,
#   '이상': 1,
#   '치매환자': 1,
#   '중': 1,
#   '기준': 2,
#   '중위소득': 1,
#   '120%(4인': 1,
#   '월': 2,
#   '648만': 1,
#   '2,000원)': 1,
#   '이하인': 1,
#   '어르신': 1,
#   '': 1,
#   '초로기': 1,
#   '치매환자도': 1,
#   '선정': 1,
#   '가능\n\n내용': 1,
#   '약제비와': 1,
#   '진료비의': 1,
#   '본인부담금을': 1,
#   '최대': 1,
#   '3만': 1,
#   '원까지': 1,
#   '지급\n\n방법': 1,
#   '보건소': 1,
#   '치매안심센터에': 1,
#   '신청\n\n문의\n': 1,
#   '보건복지상담센터(129)\n': 1,
#   '치매상담콜센터(18999988)': 1},
#  {'노인맞춤돌봄서비스\n\n대상\n\n만': 1,
#   '65세': 1,
#   '이상': 1,
#   '기초생활수급자,': 1,
#   '차상위계층': 1,
#   '또는': 2,
#   '기초연금수급자': 1,
#   '중': 1,
#   '독거·조손가구': 1,
#   '등': 3,
#   '돌봄이': 1,
#   '필요한': 1,
#   '어르신(대상자': 1,
#   '선정도구\n\n를': 1,
#   '통해': 2,
#   '우선순위에': 2,
#   '따라': 4,
#   '선정)\n\n를': 1,
#   '선정)\n\n내용\n\n안전지원,': 1,
#   '사회참여,': 1,
#   '생활교육,': 1,
#   '일상생활': 1,
#   '분야의': 1,
#   '다양한': 1,
#   '서비스를': 1,
#   '서비스': 3,
#   '제공계획에': 1,
#   '직접': 10,
#   '연계': 1,
#   '제공\n\n방문형,': 1,
#   '통원형(그룹형': 1,
#   '프로그램)': 1,
#   '제공형태': 1,
#   '다양화\n\n': 1,
#   '각': 1,
#   '대상자의': 1,
#   '돌봄욕구·필요': 1,
#   '정도에': 1,
#   '제공시간,': 1,
#   '내용': 1,
#   '지원수준이': 1,
#   '다름\n\n서비스': 1,
#   '제공': 1,
#   '분류\n\n직접': 1,
#   '서비스(안전지원)': 3,
#   '\n': 42,
#   '방문': 1,
#   '안전지원': 3,
#   '•': 9,
#   '안전·안부확인,': 2,
#   '정보제공,': 2,
#   '생활안전점검,': 1,
#   '말벗(정서지원)': 2,
#   '전화': 1,
#   'ICT': 3,
#   '관리·교육,': 1,
#   '안전·안부확인': 1,
#   '서비스(사회참여)': 2,
#   '사회관계': 1,
#   '향상': 1,
#   '프로그램': 2,
#   '여가활동,': 1,
#   '평생교육활동,': 1,
#   '문화활동': 1,
#   '자조모임': 2,
#   '서비스(생활교육)': 2,
#   '신체건강분야': 1,
#   '영양교육,': 1,
#   '보건교육,': 1,
#   '건강교육': 1,
#   '정신건강분야': 1,
#   '우울예방·인지활동': 1,
#   '서비스(일상생활': 2,
#   '지원)': 2,
#   '이동활동지원': 1,
#   '외출동행': 1,
#   '가사지원': 1,
#   '식사관리,': 1,
#   '청소관리': 1,
#   '연계서비스': 1,
#   '': 5,
#   '생활지원연계,': 1,
#   '주거개선연계,': 1,
#   '건강지원연계,': 1,
#   '기타서비스': 1,
#   '특화서비스': 2,
#   '개별': 1,
#   '맞춤형': 1,
#   '사례관리,': 1,
#   '집단활동,': 1,
#   '우울증': 1,
#   '진단': 1,
#   '및': 2,
#   '투약': 1,
#   '지원\n\n방법\n\n읍면동': 1,
#   '주민센터(행정복지센터)에': 1,
#   '신청서': 1,
#   '접수': 1,
#   '대상자': 2,
#   '선정조사': 1,
#   '상담(수행기관)': 1,
#   '결정(시군구)': 1,
#   '서비스제공(수행기관)\n\n': 1,
#   '특화서비스의': 1,
#   '경우': 1,
#   '수행기관으로': 1,
#   '접수도': 1,
#   '가능\n\n문의\n\n보건복지상담센터(129)': 1},
#  {'어르신을': 1,
#   '위한': 1,
#   '요금감면': 1,
#   '제도\n\n교통비': 1,
#   '\n': 28,
#   '65세': 3,
#   '이상': 5,
#   '어르신': 2,
#   '•': 13,
#   '철도요금': 1,
#   '감면': 11,
#   '지하철': 1,
#   '무료': 1,
#   '이용,': 1,
#   'KTX·새마을호·무궁화호': 1,
#   '30%': 3,
#   '(KTX·새마을호는': 1,
#   '토·일,': 1,
#   '공휴일': 1,
#   '제외),': 1,
#   '통근열차': 1,
#   '50%': 4,
#   '항공요금': 1,
#   '대한항공': 1,
#   '국내선·국제선': 1,
#   '10%': 2,
#   '감면(단,': 1,
#   '성수기,': 1,
#   '일부노선': 1,
#   '제외)': 2,
#   '국내연안여객선': 1,
#   '여객운임': 1,
#   '20%': 1,
#   '이용': 1,
#   '시': 4,
#   '신분증': 2,
#   '제시': 2,
#   '철도(코레일': 1,
#   '15447788)': 1,
#   '항공(대한항공': 1,
#   '15882001)': 1,
#   '여객선(한국해운조합': 1,
#   '0260962000)': 1,
#   '문화활동비': 1,
#   '고궁,': 1,
#   '능원,': 1,
#   '국·공립박물관,': 1,
#   '국·공립': 1,
#   '공원,': 1,
#   '국·공립미술관': 1,
#   '무료입장': 1,
#   '국·공립국악원': 1,
#   '입장료': 2,
#   '할인': 2,
#   '국가·지자체가': 1,
#   '운영하는': 1,
#   '공연장(대관공연': 1,
#   '입장': 1,
#   '국민건강보험료': 2,
#   '어르신이': 1,
#   '있는': 2,
#   '지역가입자': 1,
#   '소득·재산요건': 1,
#   '만족': 1,
#   '최대': 2,
#   '할인,': 1,
#   '1등급': 1,
#   '소득': 4,
#   '360만원': 3,
#   '이하이고': 3,
#   '재산이': 3,
#   '6,000만원': 1,
#   '이하일때': 3,
#   '경감률': 3,
#   '30%,': 1,
#   '2등급': 1,
#   '9,000만원': 1,
#   '20%,': 1,
#   '3등급': 1,
#   '1억': 2,
#   '3,500만원': 1,
#   '국민건강보험공단(15771000)': 2,
#   '70세': 1,
#   '어르신만': 1,
#   '지역자입자': 1,
#   '재산': 1,
#   '3,500만': 1,
#   '원': 2,
#   '이하': 1,
#   '및': 1,
#   '360만': 1,
#   '이하인': 1,
#   '경우': 2,
#   '경감': 1,
#   '통신요금': 1,
#   '기초연금수급자': 1,
#   '월': 1,
#   '청구된': 2,
#   '이용금액이': 1,
#   '2만': 1,
#   '2,000원(부가세': 1,
#   '별도)': 1,
#   '미만인': 1,
#   '월정액,': 1,
#   '음성통화료,': 1,
#   '데이터통화료를': 1,
#   '합쳐': 1,
#   '최종': 1,
#   '금액의': 1,
#   '1만': 1,
#   '1,000원': 1,
#   '기초연금': 1,
#   '신청': 4,
#   '이동전화': 1,
#   '요금': 1,
#   '동시': 1,
#   '방문신청': 1,
#   '전국': 1,
#   '읍면동': 1,
#   '주민센터(행정복지센터),': 2,
#   '국민연금공단': 1,
#   '지사': 1,
#   '방문': 1,
#   '온라인신청': 1,
#   '복지로': 1,
#   '(www.bokjiro.go.kr),': 1,
#   '정부24(www.gov.kr)': 1,
#   '전화신청': 1,
#   '전용': 1,
#   'ARS(휴대전화': 1,
#   '1523),': 1,
#   '고객센터(휴대전화': 1,
#   '114)': 1,
#   '각종공공요금': 1,
#   '노인복지시설': 1,
#   '도시가스요금': 1,
#   '전기요금': 1,
#   '상수도요금,': 1,
#   '하수도사용료': 1,
#   '시설에서': 1,
#   '산업통상자원부(15770900),': 1,
#   '한국전력공사(123),': 1,
#   '환경부(15778866)': 1},
#  {'노인보호': 1,
#   '전문기관': 1,
#   '이용\n\n대상\n\n학대피해': 1,
#   '어르신': 2,
#   '및': 5,
#   '그': 1,
#   '가족,': 1,
#   '학대행위자\n\n내용\n\n•': 1,
#   '전문상담': 1,
#   '심리치료': 1,
#   '지원,': 1,
#   '일시보호서비스,': 1,
#   '의료지원,': 1,
#   '사회복지서비스,': 1,
#   '법률지원': 1,
#   '연계': 1,
#   '\n': 3,
#   '•': 3,
#   '노인학대': 2,
#   '예방교육': 1,
#   '': 9,
#   ',': 2,
#   '노인인권': 1,
#   '교육': 1,
#   '중앙·지역노인': 1,
#   '학대사례': 1,
#   '판정위원회': 1,
#   '운영,': 1,
#   '지역사회': 1,
#   '연계망': 1,
#   '구축': 1,
#   '후원,': 1,
#   '자원봉사': 1,
#   '사업': 1,
#   '노인': 1,
#   '인식개선': 1,
#   '홍보,': 1,
#   '학술행사,': 1,
#   '캠페인,': 1,
#   '이동상담,': 1,
#   '카툰': 1,
#   '사진전시회,': 1,
#   '노인학대예방의': 1,
#   '날(6.15)': 1,
#   '기념행사\n\n방법\n\n노인보호전문기관': 1,
#   '상담을': 1,
#   '통해': 1,
#   '지원\n\n문의\n\n노인보호전문기관(15771389),': 1,
#   '수사기관(112)\n\n보건복지부콜센터(129)\n\n노인학대': 1,
#   '신고앱': 2,
#   '나비새김(노인지킴이)\n\n알려드립니다\n\n어르신': 1,
#   '학대의': 1,
#   '유형은': 1,
#   '어떻게': 2,
#   '되나요\n\n신체적': 1,
#   '학대': 6,
#   '신체적': 1,
#   '손상,': 1,
#   '고통,': 1,
#   '장애': 1,
#   '등을': 1,
#   '유발하는': 1,
#   '행위\n\n정서적': 1,
#   '비난,': 1,
#   '모욕,': 1,
#   '위협,': 1,
#   '협박': 1,
#   '등': 3,
#   '정서적': 1,
#   '고통을': 1,
#   '주는': 1,
#   '행위\n\n성적': 1,
#   '성적': 2,
#   '수치심': 1,
#   '유발행위': 1,
#   '성폭력': 1,
#   '강제적': 1,
#   '행위\n\n경제적': 1,
#   '어르신의': 2,
#   '의사에': 1,
#   '반하여': 1,
#   '재산': 1,
#   '또는': 2,
#   '권리를': 1,
#   '빼앗는': 1,
#   '행위\n\n방임': 1,
#   '의식주': 1,
#   '의료를': 1,
#   '적절하게': 1,
#   '제공하지': 1,
#   '않는': 1,
#   '행위(어르신': 1,
#   '스스로': 1,
#   '최소한의': 1,
#   '자기보호를': 1,
#   '포기하는': 1,
#   '자기방임': 1,
#   '포함)\n\n유기': 1,
#   '보호자': 1,
#   '부양의무자가': 1,
#   '어르신을': 1,
#   '버리는': 1,
#   '행위\n\n어르신': 1,
#   '사례를': 1,
#   '발견하면': 1,
#   '해야': 1,
#   '하나요\n\n어르신': 1,
#   '학대를': 1,
#   '알게': 1,
#   '되거나': 1,
#   '의심되는': 2,
#   '경우': 1,
#   '당황하지': 1,
#   '말고': 1,
#   '학대행위자로': 1,
#   '사람의': 1,
#   '주요정보,': 1,
#   '상황': 1,
#   '학대와': 1,
#   '관련된': 1,
#   '정보를': 1,
#   '즉시': 1,
#   '노인보호전문기관(15771389),': 1,
#   '수사기관(112),': 1,
#   '보건복지부콜센터(129),': 1,
#   '나비새김(노인지킴이)에': 1,
#   '신고하면': 1,
#   '됩니다.': 1,
#   '신고자의': 1,
#   '비밀은': 1,
#   '보장됩니다.': 1},
#  {'어르신': 2,
#   '문화활동': 1,
#   '지원\n\n대상': 1,
#   '60세': 1,
#   '이상': 1,
#   '국민\n\n내용': 1,
#   '지역적': 1,
#   '특성에': 1,
#   '맞춘': 1,
#   '맞춤형': 1,
#   '문화예술활동(음악,': 1,
#   '연극,': 1,
#   '무용,': 1,
#   '사진,': 1,
#   '전통분야': 1,
#   '등)을': 1,
#   '무료로': 1,
#   '운영': 2,
#   '및': 1,
#   '전국단위': 1,
#   '실버문화페스티벌': 1,
#   '개최\n\n방법': 1,
#   '문화원,': 1,
#   '문화의집': 1,
#   '등': 1,
#   '가까운': 1,
#   '문화시설': 1,
#   '이용\n\n': 1,
#   '매년': 1,
#   '문화시설별': 1,
#   '프로그램': 1,
#   '내용이': 1,
#   '다를': 1,
#   '수': 1,
#   '있으므로': 1,
#   '한국문화원연합회를': 1,
#   '통해': 1,
#   '주변': 1,
#   '지역': 1,
#   '문화프로그램에': 1,
#   '대해': 1,
#   '사전': 1,
#   '문의': 1,
#   '필요\n\n문의': 1,
#   '한국문화원연합회': 1,
#   '지역문화진흥팀(027044332,': 1,
#   '2379)': 1},
#  {'노후긴급자금': 1,
#   '대부': 1,
#   '사업\n\n대상': 1,
#   '만': 1,
#   '60세': 1,
#   '이상의': 1,
#   '국민연금': 1,
#   '수급자\n\n내용': 1,
#   '\n': 3,
#   '전·월세자금,': 1,
#   '의료비,': 1,
#   '배우자': 1,
#   '장제비,': 1,
#   '재해복구비의': 1,
#   '긴급': 1,
#   '생활안정자금을': 1,
#   '저금리로': 1,
#   '대출\n': 1,
#   '연간': 1,
#   '연금수령액의': 1,
#   '2배': 1,
#   '이내,': 1,
#   '최고': 1,
#   '1,000만': 1,
#   '원까지': 1,
#   '대출': 1,
#   '가능\n': 1,
#   '': 1,
#   '최대': 1,
#   '5년': 1,
#   '원금균등': 1,
#   '분할상환(거치': 1,
#   '12년': 1,
#   '선택,': 1,
#   '최장': 1,
#   '7년)\n\n방법': 1,
#   '수급자': 1,
#   '본인이': 1,
#   '국민연금공단': 2,
#   '지사에': 1,
#   '직접': 1,
#   '방문해': 1,
#   '신청\n\n문의': 1,
#   '콜센터(1355)': 1},
#  {'노인': 1,
#   '틀니': 1,
#   '지원\n\n대상\n\n완전틀니': 1,
#   '만': 2,
#   '65세': 2,
#   '이상으로': 2,
#   '윗잇몸': 1,
#   '또는': 3,
#   '아랫잇몸에': 1,
#   '치아가': 1,
#   '하나도': 1,
#   '없는': 1,
#   '어르신\n\n부분틀니': 1,
#   '남은': 1,
#   '치아를': 1,
#   '이용해': 1,
#   '부분틀니': 1,
#   '제작이': 1,
#   '가능한': 1,
#   '어르신\n\n내용\n\n완전틀니(레진상,': 1,
#   '금속상),': 1,
#   '부분틀니(고리': 1,
#   '유지형': 1,
#   '금속상)': 1,
#   '시술': 1,
#   '시': 3,
#   '비용': 1,
#   '일부만': 1,
#   '본인이': 1,
#   '부담\n\n30%': 1,
#   '\n': 3,
#   '515%': 1,
#   '5%': 1,
#   '15%\n\n방법\n\n건강보험대상자': 1,
#   '치과': 2,
#   '병·의원': 2,
#   '건강보험공단': 1,
#   '지사에': 1,
#   '대상자': 2,
#   '등록': 2,
#   '신청\n\n의료급여수급자': 1,
#   '및': 1,
#   '시군구': 1,
#   '읍면동': 1,
#   '주민센터(행정복지센터)에': 1,
#   '신청\n\n문의\n\n국민건강보험공단(15771000)\n\n보건복지상담센터(129)\n\n알려드립니다\n\n틀니,': 1,
#   '깨끗하고': 1,
#   '튼튼하게': 1,
#   '사용하는': 1,
#   '법\n\n치약으로': 1,
#   '닦지': 1,
#   '마세요.': 1,
#   '치약은': 1,
#   '표면을': 1,
#   '쉽게': 1,
#   '마모시키기': 1,
#   '때문에': 1,
#   '반드시': 1,
#   '전용': 2,
#   '세정제를': 1,
#   '사용해야': 1,
#   '합니다.\n\n뜨거운': 1,
#   '물': 1,
#   '소독도': 1,
#   '피해야': 1,
#   '합니다.': 1,
#   '모양이': 1,
#   '망가지기': 1,
#   '쉽습니다.\n\n부드러운': 1,
#   '칫솔모로': 1,
#   '살살': 1,
#   '닦아주는': 1,
#   '게': 1,
#   '좋습니다.\n\n하루': 1,
#   '812시간': 1,
#   '착용이': 1,
#   '적당합니다.': 1,
#   '장시간': 1,
#   '착용': 1,
#   '잇몸이': 1,
#   '붓고': 1,
#   '통증이': 1,
#   '발생합니다.': 1,
#   '잠': 1,
#   '잘': 1,
#   '때는': 1,
#   '꼭': 1,
#   '빼주세요.\n\n공기': 1,
#   '중에': 1,
#   '보관하면': 1,
#   '안': 1,
#   '됩니다.': 1,
#   '상온': 1,
#   '보관': 1,
#   '틀니가': 1,
#   '건조해서': 1,
#   '뒤틀리거나': 1,
#   '깨질': 1,
#   '수': 1,
#   '있습니다.': 1,
#   '세정제에': 1,
#   '담가': 1,
#   '보관하세요.': 1},
#  {'독거노인·장애인': 1,
#   '응급안전': 1,
#   '안심서비스\n\n대상\n\n상시보호가': 1,
#   '필요한': 1,
#   '독거어르신': 3,
#   '및': 5,
#   '장애인\n\n만': 1,
#   '65세': 1,
#   '이상': 1,
#   '중': 1,
#   '기초생활수급자,': 1,
#   '차상위계층,': 1,
#   '기초연금수급자\n\n장애인활동지원': 1,
#   '수급자이면서': 1,
#   '독거': 1,
#   '또는': 1,
#   '취약가구\n\n그': 1,
#   '외': 1,
#   '기초지자체': 1,
#   '장이': 1,
#   '생활여건,': 1,
#   '건강상태': 1,
#   '등을': 1,
#   '고려해': 1,
#   '상시': 1,
#   '보호가': 1,
#   '필요하다고': 1,
#   '인정하는': 1,
#   '장애인\n': 1,
#   '': 13,
#   '단,': 1,
#   '24시간': 1,
#   '활동지원서비스를': 1,
#   '받고': 1,
#   '있는': 1,
#   '장애인은': 1,
#   '선정': 1,
#   '제외\n\n내용\n\n독거노인과': 1,
#   '장애인': 1,
#   '가정에': 1,
#   '화재센서,': 1,
#   '활동감지기': 1,
#   '응급호출기를': 1,
#   '설치하여': 1,
#   '응급상황': 1,
#   '발생': 1,
#   '시': 2,
#   '신속하게': 1,
#   '대처할': 1,
#   '수': 1,
#   '있도록': 1,
#   '119에': 2,
#   '신고\n': 2,
#   '활동량감지기': 1,
#   '침실,': 1,
#   '화장실,': 1,
#   '거실': 1,
#   '주방에서의': 1,
#   '활동량을': 1,
#   '감지\n': 1,
#   '게이트웨이': 1,
#   '태블릿일체형': 1,
#   '게이트웨이,': 1,
#   '활동량(심박': 1,
#   '호흡)감지': 1,
#   '등\n': 1,
#   '응급호출기': 1,
#   '벽면부착시': 1,
#   '응급호출기이며,': 1,
#   '호출버튼을': 1,
#   '누를': 1,
#   '119(소방청)으로': 1,
#   '전화연결\n': 1,
#   '화재감지기': 1,
#   '연기를': 1,
#   '감지하여': 2,
#   '화재상황을': 1,
#   '알리고': 1,
#   '게이트웨이를': 1,
#   '통하여': 1,
#   '출입문감지기': 1,
#   '출입문의': 1,
#   '개체여부를': 1,
#   '외출과': 1,
#   '재실상태': 1,
#   '인지\n\n방법\n\n사업대상자': 1,
#   '추천': 1,
#   '대상자': 3,
#   '발굴': 1,
#   '서비스': 3,
#   '신청': 1,
#   '신청서': 1,
#   '접수': 1,
#   '승인요청': 1,
#   '승인': 1,
#   '댁내장비': 1,
#   '설치': 1,
#   '제공': 1,
#   '종결\n\n문의\n\n보건복지상담센터(129)': 1},
#  {'기초연금제도\n\n대상': 1,
#   '만': 3,
#   '65세': 3,
#   '이상이며,': 1,
#   '소득인정액이': 1,
#   '선정기준액(소득하위': 1,
#   '70%)': 1,
#   '이하인': 1,
#   '어르신\n\n내용': 1,
#   '월': 3,
#   '최대': 4,
#   '32만': 2,
#   '3,180원까지': 1,
#   '지원\n\n소득하위': 1,
#   '70%': 1,
#   '\n': 2,
#   '단독가구': 1,
#   '202만': 1,
#   '원,': 1,
#   '부부가구': 1,
#   '323만': 1,
#   '2,000': 1,
#   '원': 5,
#   '단독가구는': 1,
#   '3,180': 1,
#   ',': 1,
#   '부부가구는': 1,
#   '51만': 1,
#   '7,080': 1,
#   '원(1인당': 1,
#   '25만': 1,
#   '8,540': 1,
#   '원)\n\n방법\n': 1,
#   '전국': 1,
#   '읍면동': 1,
#   '주민센터(행정복지센터)': 1,
#   '또는': 1,
#   '국민연금공단': 2,
#   '지사': 1,
#   '방문\n': 1,
#   '복지로(www.bokjiro.go.kr)': 1,
#   '온라인': 1,
#   '신청\n': 1,
#   '': 3,
#   '미만이신': 1,
#   '분들은': 1,
#   '생일이': 1,
#   '속하는': 1,
#   '달의': 1,
#   '1개월': 1,
#   '전': 1,
#   '초일부터': 1,
#   '신청': 1,
#   '가능\n': 1,
#   '방문이': 1,
#   '어려운': 1,
#   '경우': 1,
#   '국민연금공단의': 1,
#   '찾아뵙는': 1,
#   '서비스(1355)를': 1,
#   '신청\n\n문의\n': 1,
#   '보건복지상담센터(129)\n': 1,
#   '콜센터(1355)\n': 1,
#   '기초연금': 3,
#   '누리집(basicpension.mohw.go.kr)\n\n알려드립니다\n\n기초연금의': 1,
#   '선정기준이': 1,
#   '되는': 1,
#   '소득인정액은': 1,
#   '어르신의': 2,
#   '소득평가액과': 1,
#   '재산의': 1,
#   '소득환산액을': 1,
#   '합산한': 1,
#   '금액으로': 1,
#   '반영됩니다.(부양의무자': 1,
#   '기준': 1,
#   '미적용)\n\n근로활동을': 1,
#   '하는': 1,
#   '근로의욕이': 1,
#   '저하되지': 1,
#   '않도록': 1,
#   '일용근로소득,': 1,
#   '공공일자리소득,': 1,
#   '자활근로소득은': 1,
#   '소득으로': 1,
#   '산정하지': 1,
#   '않습니다.\n\n직역연금': 1,
#   '수급권을': 1,
#   '가진': 1,
#   '어르신은': 1,
#   '지급대상에서': 1,
#   '제외될': 1,
#   '수': 1,
#   '있습니다.\n\n2023년,': 1,
#   '이렇게': 1,
#   '달라집니다\n\n2023년': 1,
#   '1월부터': 1,
#   '상시근로소득에서': 1,
#   '108만': 2,
#   '공제': 1,
#   '후': 1,
#   '30%': 1,
#   '추가': 1,
#   '공제가': 1,
#   '적용됩니다.\n\n': 1,
#   '(22년)': 1,
#   '103만': 1,
#   '(23년)': 1},
#  {'노인': 3,
#   '안검진': 1,
#   '및': 3,
#   '개안수술\n\n대상\n\n노인': 1,
#   '안': 2,
#   '검진': 2,
#   '\n': 8,
#   '만': 2,
#   '60세': 2,
#   '이상': 2,
#   '어르신(저소득층': 1,
#   '우선)': 1,
#   '개안수술': 2,
#   '기초생활수급자,': 1,
#   '차상위계층,': 1,
#   '한부모가족': 1,
#   '어르신\n\n내용\n\n노인': 1,
#   '•': 2,
#   '1차진단': 1,
#   '정밀': 2,
#   '안저검사': 1,
#   '1종': 1,
#   '': 5,
#   '2차진단': 1,
#   '안저검사,': 1,
#   '안압검사,': 1,
#   '굴절검사': 1,
#   '조절검사': 1,
#   '(안경': 1,
#   '처방전': 1,
#   '교부': 1,
#   '포함),': 1,
#   '각막': 1,
#   '곡률검사': 1,
#   '등': 3,
#   '총': 1,
#   '4종': 1,
#   '백내장,': 1,
#   '망막질환': 1,
#   '안질환자의': 1,
#   '개안': 1,
#   '수술비용': 1,
#   '본인부담금': 1,
#   '전액': 1,
#   '지급': 1,
#   '지원': 2,
#   '제외': 1,
#   '개안수술과': 1,
#   '관련': 1,
#   '없는': 1,
#   '질병': 1,
#   '치료비,': 1,
#   '간병비·상급병실료': 1,
#   '비급여,': 1,
#   '결정': 1,
#   '전에': 1,
#   '발생한': 1,
#   '진료비': 1,
#   '등\n\n방법\n': 1,
#   '시군구': 1,
#   '보건소에': 1,
#   '문의': 1,
#   '후': 1,
#   '신청\n\n문의\n': 1,
#   '보건복지상담센터(129)\n': 1,
#   '한국실명예방재단(027181102)': 1},
#  {'주택연금제도\n\n대상': 1,
#   '\n': 4,
#   '보유': 1,
#   '주택이': 1,
#   '공시': 1,
#   '가격': 1,
#   '등': 3,
#   '9억': 4,
#   '원': 4,
#   '이하인': 1,
#   '만': 1,
#   '55세': 2,
#   '이상': 1,
#   '어르신\n': 1,
#   '': 7,
#   '다주택자라도': 1,
#   '합산가격이': 1,
#   '공시가격': 4,
#   '이하이면': 1,
#   '가입': 2,
#   '가능\n': 1,
#   '등이': 1,
#   '초과': 1,
#   '2주택자는': 1,
#   '3년': 1,
#   '이내': 1,
#   '1주택': 1,
#   '처분': 1,
#   '조건으로': 1,
#   '가능\n\n내용': 1,
#   '집을': 1,
#   '담보로': 1,
#   '맡기고': 1,
#   '내': 1,
#   '집에': 1,
#   '살면서': 1,
#   '매월': 3,
#   '연금': 1,
#   '수령\n': 1,
#   '지원예시\n': 1,
#   '집값이': 1,
#   '3억': 1,
#   '원인': 1,
#   '가입자는': 2,
#   '45만': 1,
#   '3,000원,': 1,
#   '70세': 1,
#   '90만': 1,
#   '1,000원의': 1,
#   '연금수령(종신지급,': 1,
#   '정액형': 1,
#   '이용,': 1,
#   '부부의': 1,
#   '경우': 3,
#   '연소자': 1,
#   '연령,': 1,
#   '2023년': 1,
#   '3월': 1,
#   '1일': 1,
#   '기준)\n': 1,
#   '일정한도': 1,
#   '내에서': 1,
#   '목돈으로': 1,
#   '한': 1,
#   '번에': 1,
#   '인출해': 1,
#   '의료비,': 1,
#   '주택수선비,': 1,
#   '선순위': 1,
#   '대출': 1,
#   '상환용도로': 1,
#   '사용': 1,
#   '가능': 1,
#   '지원예시\n\n방법': 1,
#   '한국주택금융공사': 1,
#   '방문': 1,
#   '또는': 1,
#   '온라인': 1,
#   '신청\n\n문의': 1,
#   '한국주택금융공사(16888114,': 1,
#   'www.hf.go.kr)\n\n알려드립니다\n\n주택연금을': 1,
#   '이용하는': 2,
#   '도중': 2,
#   '사망할': 1,
#   '배우자가': 1,
#   '계속': 2,
#   '이용할': 2,
#   '수': 3,
#   '있나요\n\n배우자가': 1,
#   '채무인수(6개월': 1,
#   '이내)하여': 1,
#   '있으며,': 1,
#   '연금금액은': 1,
#   '감액': 1,
#   '없이': 1,
#   '기존과': 1,
#   '동일하게': 1,
#   '지급됩니다.\n\n주택연금을': 1,
#   '이사할': 1,
#   '계약이': 1,
#   '해지되나요\n\n이사': 1,
#   '후에도': 1,
#   '공사의': 1,
#   '담보주택': 1,
#   '변경': 1,
#   '승인을': 1,
#   '받아': 1,
#   '새로운': 1,
#   '주택으로': 1,
#   '변경할': 1,
#   '있습니다.': 1,
#   '다만,': 1,
#   '신규주택의': 1,
#   '등은': 1,
#   '조건변경': 1,
#   '승인일을': 1,
#   '기준으로': 1,
#   '이하이거나': 1,
#   '기존': 1,
#   '주택': 1,
#   '보다': 1,
#   '낮거나': 1,
#   '같아야': 1,
#   '합니다.\n부동산': 1,
#   '가격공시에': 1,
#   '관한': 1,
#   '법률에': 1,
#   '따라': 1,
#   '공시된': 1,
#   '가격\n\n연금으로': 1,
#   '받은': 1,
#   '금액이': 1,
#   '집값보다': 1,
#   '적거나': 1,
#   '집값을': 2,
#   '초과하면': 1,
#   '어떻게': 1,
#   '되나요\n\n정산절차를': 1,
#   '통해': 1,
#   '남는': 1,
#   '부분은': 1,
#   '상속인에게': 2,
#   '돌아가고,': 1,
#   '초과하더라도': 1,
#   '부족분에': 1,
#   '대해': 1,
#   '별도로': 1,
#   '청구하지': 1,
#   '않습니다.': 1},
#  {'노인': 1,
#   '치과': 3,
#   '임플란트': 4,
#   '지원\n\n대상\n\n만': 1,
#   '65세': 1,
#   '이상': 1,
#   '부분': 2,
#   '무치악환자(치아가': 1,
#   '완전히': 1,
#   '없는': 1,
#   '경우': 1,
#   '제외)\n': 1,
#   '알려드립니다\n': 1,
#   '': 33,
#   '무치악이란': 1,
#   '윗잇몸': 1,
#   '또는': 3,
#   '아랫잇몸에': 1,
#   '일부': 1,
#   '치아가': 1,
#   '빠진': 1,
#   '상태를': 1,
#   '말합니다.\n\n내용\n\n치과': 1,
#   '시술': 1,
#   '시': 1,
#   '해당': 1,
#   '비용': 1,
#   '일부만': 1,
#   '본인이': 1,
#   '부담(평생': 1,
#   '2개)\n\n본인부담률\n': 1,
#   '건강보험': 1,
#   '차상위': 1,
#   '의료급여': 2,
#   '1종': 1,
#   '2종': 1,
#   '\n\n': 1,
#   '30%': 1,
#   '1020%': 1,
#   '10%': 1,
#   '20%': 1,
#   '\n\n방법\n\n건강보험대상자': 1,
#   '병·의원': 2,
#   '건강보험공단': 1,
#   '지사에': 1,
#   '대상자': 2,
#   '등록': 2,
#   '신청\n\n의료급여수급자': 1,
#   '및': 1,
#   '시군구': 1,
#   '읍면동': 1,
#   '주민센터(행정복지센터)에': 1,
#   '신청\n\n문의\n\n국민건강보험공단(15771000)\n\n보건복지상담센터(129)\n\n자주': 1,
#   '하는': 1,
#   '질문\n\n부분틀니를': 1,
#   '지원받은': 2,
#   '후': 1,
#   '시술을': 1,
#   '해도': 1,
#   '비용을': 1,
#   '지원받을': 2,
#   '수': 2,
#   '있나요\n\n부분틀니를': 1,
#   '경우라도': 1,
#   '평생': 1,
#   '2개의': 1,
#   '임플란트를': 1,
#   '있습니다.': 1},
#  {'노인': 11,
#   '일자리': 5,
#   '및': 5,
#   '사회활동': 4,
#   '지원\n\n대상': 1,
#   '\n': 15,
#   '구분': 2,
#   '': 40,
#   '지원대상': 1,
#   '\n\n': 2,
#   '사회활동(공익활동)': 2,
#   '만': 8,
#   '65세': 2,
#   '이상': 8,
#   '기초연금': 1,
#   '수급자': 1,
#   '사회활동(사회서비스형': 2,
#   '선도모델(시범사업))': 2,
#   '60세': 6,
#   '일자리(사회서비스형)': 2,
#   '일자리(시장형사업단)': 2,
#   '일자리(취업알선형)': 2,
#   '일자리(시니어인턴십)': 2,
#   '일자리(고령자친화기업)': 2,
#   '일부': 1,
#   '유형': 1,
#   '한정하여': 1,
#   '참여': 1,
#   '허용\n\n내용': 1,
#   '\n다양한': 1,
#   '지원\n': 1,
#   '지원내용': 1,
#   '지역사회': 1,
#   '공익': 1,
#   '증진': 1,
#   '프로그램': 2,
#   '참여(월': 1,
#   '30시간': 1,
#   '이상,': 1,
#   '27만': 1,
#   '원': 1,
#   '활동수당)\n\n노노케어,': 1,
#   '취약계층': 1,
#   '지원,': 1,
#   '공공시설': 1,
#   '봉사,': 1,
#   '경륜전수활동': 1,
#   '등': 4,
#   '외부자원': 1,
#   '(인적·물적)을': 1,
#   '활용한': 1,
#   '사회서비스': 1,
#   '분야': 1,
#   '신노년세대': 1,
#   '맞춤형': 1,
#   '취약계층시설': 1,
#   '활동보조': 1,
#   '(월': 1,
#   '60시간,': 1,
#   '월': 1,
#   '급여': 1,
#   '최대': 1,
#   '59만': 1,
#   '4,000': 1,
#   '원(주휴수당': 1,
#   '연차수당': 1,
#   '별도))\n\n지역아동센터·장애인거주시설': 1,
#   '식사보조,': 1,
#   '환경정리': 1,
#   '노인일자리': 3,
#   '수행기관이': 1,
#   '운영하는': 1,
#   '매장·사업단에서': 1,
#   '활동\n\n식품': 1,
#   '제조·판매,': 1,
#   '매장': 1,
#   '운영,': 1,
#   '택배': 1,
#   '관련직종': 1,
#   '업무능력': 1,
#   '보유자를': 1,
#   '수요처로': 1,
#   '연계\n\n경비·청소·가사·간병인': 1,
#   '민간기업': 1,
#   '취업지원\n\n기업인턴': 1,
#   '(3개월)': 1,
#   '후': 1,
#   '계속고용': 1,
#   '유도(기업대상': 1,
#   '인건비': 1,
#   '지원)': 1,
#   '노인다수': 1,
#   '고용기업': 1,
#   '또는': 1,
#   '우수': 1,
#   '노인고용기업': 1,
#   '지원\n\n인증형,': 1,
#   '창업형': 1,
#   '\n\n방법\n\n주민센터(행정복지센터),': 1,
#   '수행기관(시니어클럽,': 1,
#   '노인복지관': 1,
#   '등)에': 1,
#   '신청\n\n문의': 1,
#   '상담안내(15443388)\n': 1,
#   '한국노인인력개발원': 1,
#   '지역본부\n\n자주': 1,
#   '하는': 1,
#   '질문\n\n노인': 1,
#   '지원': 2,
#   '사업': 1,
#   '참여로': 1,
#   '받는': 1,
#   '활동비도': 1,
#   '기초연금대상자': 2,
#   '선정': 2,
#   '시': 2,
#   '소득으로': 1,
#   '보나요\n\n노인': 1,
#   '사업의': 1,
#   '활동비는': 1,
#   '근로': 1,
#   '소득에서': 1,
#   '제외합니다.': 1},
#  {'청소년상담': 1,
#   '1388\n\n대상\n\n만': 1,
#   '9세24세': 1,
#   '청소년\n\n내용\n\n일상적인': 1,
#   '고민부터': 1,
#   '다양한': 1,
#   '위기(가족갈등,': 1,
#   '교우관계': 1,
#   '문제,': 1,
#   '학업중단,': 1,
#   '가출,': 1,
#   '인터넷': 1,
#   '중독,': 1,
#   '진로': 1,
#   '및': 2,
#   '학업': 1,
#   '문제': 1,
#   '등)를': 1,
#   '겪고': 1,
#   '있는': 1,
#   '청소년에게': 1,
#   '상담': 3,
#   '서비스': 1,
#   '제공\n\n방법\n\n전화,': 1,
#   '모바일(문자,': 1,
#   '카카오톡,': 1,
#   '페이스북),': 1,
#   '사이버(채팅': 1,
#   '게시판)': 1,
#   '상담\n\n문의\n\n청소년': 1,
#   '전화': 1,
#   '': 4,
#   '1388': 1,
#   '또는': 1,
#   '지역번호1388로': 1,
#   '전화\n\n문자상담': 1,
#   '1388번으로': 1,
#   '문자상담\n\n카카오톡·페이스북상담': 1,
#   '청소년상담1388': 1,
#   '검색': 1,
#   '후': 1,
#   '상담\n\n사이버(인터넷': 1,
#   '채팅)': 1,
#   'www.cyber1388.kr에': 1,
#   '접속해서': 1,
#   '채팅방': 1,
#   '참여': 1},
#  {'아동': 1,
#   '급식': 1,
#   '지원\n\n대상\n\n저소득층': 1,
#   '가정의': 1,
#   '결식': 1,
#   '우려가': 1,
#   '있는': 1,
#   '18세': 1,
#   '미만': 1,
#   '아동\n\n내용\n\n단체급식소': 1,
#   '및': 1,
#   '일반음식점': 1,
#   '이용\n\n도시락': 1,
#   '배달\n\n부식': 1,
#   '지원\n\n식품권': 1,
#   '제공\n\n급식카드': 1,
#   '발급': 1,
#   '등으로': 1,
#   '급식지원\n\n방법\n\n전국': 1,
#   '읍면동': 2,
#   '주민센터(행정복지센터)': 1,
#   '방문': 1,
#   '신청,': 1,
#   '(전자)우편': 1,
#   '등\n\n복지로': 1,
#   '온라인': 1,
#   '신청(www.bokjiro.go.kr)\n\n문의\n\n전국': 1,
#   '주민센터(행정복지센터)\n\n보건복지상담센터(129)': 1},
#  {'가정위탁아동': 1,
#   '지원(드림스타트사업)\n\n대상\n\n친부모가': 1,
#   '직접': 1,
#   '양육할': 1,
#   '수': 1,
#   '없어': 1,
#   '자격을': 1,
#   '갖춘': 1,
#   '위탁가정에서': 1,
#   '보호하고': 1,
#   '있는': 1,
#   '아동\n\n\n부모의': 1,
#   '질병,': 1,
#   '가출,': 1,
#   '실직,': 1,
#   '수감,': 1,
#   '사망,': 1,
#   '그': 1,
#   '밖의': 1,
#   '사유로': 1,
#   '보호가': 2,
#   '필요하거나': 1,
#   '아동학대로': 1,
#   '분리보호가': 1,
#   '필요한': 2,
#   '아동\n\n\n전문가정위탁': 1,
#   '학대피해': 2,
#   '아동,': 1,
#   '2세': 1,
#   '이하': 1,
#   '아동': 3,
#   '등': 4,
#   '특별한': 1,
#   '아동을': 3,
#   '전문적으로': 1,
#   '보호·양육\n\n일반가정위탁': 1,
#   '전문가정위탁': 1,
#   '대상에': 1,
#   '해당하지': 1,
#   '않는': 1,
#   '보호·양육\n일시가정위탁': 1,
#   '보호대상': 1,
#   '일시': 1,
#   '위탁하여': 1,
#   '보호·양육(즉각분리·응급조치된': 1,
#   '영유아(만': 1,
#   '6세': 1,
#   '이하)를': 1,
#   '보호하는': 1,
#   '위기아동': 2,
#   '가정보호사업': 1,
#   '포함)\n\n내용\n\n위탁아동에': 1,
#   '대한': 1,
#   '양육보조금': 1,
#   '다양한': 1,
#   '보조금': 1,
#   '지급\n\n\n\n구분\n지원내용\n\n\n\n\n양육보조금\n만': 1,
#   '7세': 1,
#   '미만(83개월까지)': 1,
#   '월': 6,
#   '30만': 2,
#   '원\n\n\n양육보조금\n만': 2,
#   '7세부터': 1,
#   '만': 1,
#   '13세': 2,
#   '미만': 1,
#   '(84개월155개월)': 1,
#   '40만': 1,
#   '이상(156개월부터)': 1,
#   '50만': 1,
#   '원\n\n\n디딤씨앗통장\n월': 1,
#   '최대': 1,
#   '10만': 1,
#   '원\n\n\n가정위탁아동': 1,
#   '심리치료비(지원기간': 3,
#   '12개월': 3,
#   '이내)\n위탁아동': 1,
#   '심리치료비': 1,
#   '및': 3,
#   '위탁부모': 1,
#   '양육상담비': 1,
#   '20만': 2,
#   '원': 3,
#   '이내(필요': 1,
#   '시최대': 1,
#   '원까지': 1,
#   '지원)\n\n\n가정위탁아동': 1,
#   '이내)\n심리검사비': 1,
#   '원(1회)\n\n\n가정위탁아동': 1,
#   '이내)\n교통비': 1,
#   '2만': 1,
#   '이내\n\n\n상해보험료\n연': 1,
#   '6만': 2,
#   '8,500원\n\n\n전문아동보호비\n전문가정위탁,': 1,
#   '가정보호': 1,
#   '대상': 1,
#   '보호': 1,
#   '시': 2,
#   '1인당': 2,
#   '100만': 2,
#   '원\n\n\n아동용품구입비\n위탁가정': 1,
#   '책정': 1,
#   '1회': 1,
#   '지원': 1,
#   '권고\n\n상해보험': 1,
#   '단체': 1,
#   '가입을': 1,
#   '통해': 1,
#   '입원,': 2,
#   '통원': 2,
#   '의료비': 2,
#   '지급\n\n보험담보': 1,
#   '위탁아동': 2,
#   '부양자': 1,
#   '1인의': 1,
#   '후유장해,': 1,
#   '지원\n보험료': 1,
#   '연': 1,
#   '8,500원': 1,
#   '이내': 1,
#   '내외\n\n방법\n\n위탁가정': 1,
#   '보호자가': 1,
#   '아동의': 1,
#   '거주지': 1,
#   '시군구청': 1,
#   '읍면동': 1,
#   '주민센터(행정복지센터)에': 1,
#   '신청\n\n문의\n\n보건복지상담센터(129)': 1},
#  {'푸른등대': 1,
#   '삼성기부장학사업\n\n대상\n\n국내': 1,
#   '4년제': 1,
#   '및': 2,
#   '전문': 1,
#   '대학교': 1,
#   '재학생': 1,
#   '중': 2,
#   '장애인': 1,
#   '가정,': 2,
#   '새터민(탈북주민)': 1,
#   '가정': 1,
#   '외': 1,
#   '보호시설': 1,
#   '출신,': 1,
#   '학생가장,': 1,
#   '조손가정,': 1,
#   '기초생활차상위계층,': 1,
#   '한부모가족,': 1,
#   '다문화가정,': 1,
#   '주거비지원': 1,
#   '필요자,': 1,
#   '기타': 1,
#   '사회적배려계층': 1,
#   '신청자격을': 1,
#   '충족하여': 1,
#   '대학의': 1,
#   '추천을': 1,
#   '받은': 1,
#   '자\n': 1,
#   '': 2,
#   '전공대,': 1,
#   '대학원대,': 1,
#   '방송통신대,': 1,
#   '원격대,': 1,
#   '사이버대,': 1,
#   '기능대,': 1,
#   '평생교육원': 1,
#   '제외\n\n내용\n\n지원금액': 1,
#   '\n': 7,
#   '학기당': 1,
#   '150만': 1,
#   '원': 1,
#   '지원기간': 1,
#   '2개': 1,
#   '학기(휴학,': 1,
#   '편입,': 1,
#   '자퇴': 1,
#   '등': 1,
#   '학적변동': 1,
#   '시': 1,
#   '장학생': 1,
#   '자격': 1,
#   '상실': 1,
#   '반환)': 1,
#   '계속지원기준': 1,
#   '직전': 1,
#   '정규학기': 1,
#   '백분위': 1,
#   '점수': 1,
#   '70점': 1,
#   '이상\n\n방법\n\n한국장학재단': 1,
#   '누리집(httpswww.kosaf.go.kr)': 1,
#   '또는': 1,
#   '모바일': 2,
#   '앱에서': 1,
#   '신청\n': 1,
#   '대학에서': 1,
#   '추천받은': 1,
#   '학생만': 1,
#   '신청': 1,
#   '가능\n\n문의\n\n한국장학재단(15992290,': 1,
#   'www.kosaf.go.kr)\n': 1,
#   '챗봇': 1,
#   '상담(httpsmo.kosaf.go.krappslocationchatbot)': 1},
#  {'취업': 3,
#   '후': 3,
#   '상환': 3,
#   '학자금대출\n\n대상\n\n교육부': 1,
#   '또는': 1,
#   '한국장학재단과': 1,
#   '학자금대출': 1,
#   '협약을': 1,
#   '체결한': 1,
#   '국내': 1,
#   '고등교육기관': 1,
#   '(학점은행제': 1,
#   '교육기관,': 1,
#   '외국대학': 1,
#   '제외)의': 1,
#   '학부생,': 1,
#   '전문대학의': 2,
#   '전문기술석사,': 1,
#   '대학원생으로': 2,
#   '재학': 2,
#   '및': 5,
#   '입학·복학': 1,
#   '예정인': 1,
#   '대한민국': 1,
#   '국민(주민등록상': 1,
#   '해외이주': 1,
#   '신고자,': 1,
#   '영주권자': 1,
#   '재외국민': 1,
#   '제외)\n\n대상': 1,
#   '\n': 28,
#   '협약': 2,
#   '체결': 2,
#   '대학': 2,
#   '학부생': 1,
#   '대학원생': 1,
#   '전문기술석사': 1,
#   '이수': 2,
#   '중인': 1,
#   '학생': 1,
#   '연령': 1,
#   '만': 3,
#   '35세': 1,
#   '이하': 5,
#   '': 7,
#   '선취업': 1,
#   '후진학자': 1,
#   '등은': 1,
#   '45세': 1,
#   '40세': 1,
#   '성적': 1,
#   '제한없음': 3,
#   '이수학점': 1,
#   '직전학기': 1,
#   '12학점': 1,
#   '이상': 1,
#   '신입생,': 1,
#   '장애인은': 1,
#   '적용': 1,
#   '제외': 1,
#   '소득': 2,
#   '학자금지원': 3,
#   '8구간': 1,
#   '다자녀': 2,
#   '가구는': 1,
#   '무관': 1,
#   '4구간': 2,
#   '이하\n\n내용\n\n대출금리': 1,
#   '1.7%(변동금리)': 1,
#   '대출조건': 1,
#   '등록금': 2,
#   '대출(당해학기': 1,
#   '소요액': 1,
#   '전액),': 1,
#   '생활비': 3,
#   '대출(학기당': 1,
#   '150만': 1,
#   '원,': 1,
#   '단': 1,
#   '23년도': 1,
#   '1학기는': 1,
#   '200만': 1,
#   '원)': 2,
#   '대학원': 2,
#   '대출은': 1,
#   '학과·학제별': 1,
#   '총한도': 1,
#   '범위': 1,
#   '내': 1,
#   '가능하며,': 1,
#   '자세한': 1,
#   '사항은': 1,
#   '한국장학재단에': 1,
#   '문의': 1,
#   '이자지원': 1,
#   '기초,': 1,
#   '차상위': 1,
#   '가구': 1,
#   '학생은': 1,
#   '중': 1,
#   '등록금,': 1,
#   '대출': 3,
#   '이자': 1,
#   '면제': 1,
#   '학부생은': 1,
#   '의무상환': 1,
#   '개시': 1,
#   '전까지': 1,
#   '무이자': 1,
#   '지원': 1,
#   '상환방법': 1,
#   '연간': 1,
#   '소득금액이': 1,
#   '상환기준소득금액(23년': 1,
#   '기준': 1,
#   '연소득': 1,
#   '2,525만': 1,
#   '이하인': 1,
#   '경우': 1,
#   '원리금': 1,
#   '상환유예,': 1,
#   '초과': 1,
#   '시': 1,
#   '소득에': 1,
#   '따라': 1,
#   '의무상환\n\n방법\n\n한국장학재단': 1,
#   '누리집(httpswww.kosaf.go.kr)에서': 2,
#   '온라인': 1,
#   '신청': 1,
#   '모바일': 1,
#   '앱에서': 1,
#   '신청\n\n문의\n\n한국장학재단(15992000,': 1,
#   'www.kosaf.go.kr)\n\n2023년,': 1,
#   '이렇게': 1,
#   '달라집니다\n\n2023년부터': 1,
#   '학자금': 1,
#   '지원대상이': 1,
#   '일반대학원생에': 1,
#   '전문·특수': 1,
#   '확대됩니다.\n\n': 1,
#   '구체적인': 1,
#   '기준과': 1,
#   '내용은': 1,
#   '한국장학재단': 1,
#   '확인하세요.': 1},
#  {'방과후학교': 3,
#   '자유수강권\n\n대상\n\n기초생활수급자': 1,
#   '및': 1,
#   '한부모가족,': 1,
#   '차상위계층': 1,
#   '등': 2,
#   '저소득가구의': 1,
#   '초중고학생': 1,
#   '자녀\n\n시도교육청의': 1,
#   '기준에': 2,
#   '따라': 2,
#   '지원대상': 1,
#   '범위': 1,
#   '상이\n\n내용\n\n저소득층': 1,
#   '자녀가': 1,
#   '자유롭게': 1,
#   '원하는': 1,
#   '강좌를': 1,
#   '선택해': 1,
#   '수강할': 1,
#   '수': 1,
#   '있도록': 1,
#   '1인당': 1,
#   '연간': 1,
#   '60만': 1,
#   '원': 1,
#   '내외에서': 1,
#   '수강료(강사료,': 1,
#   '도서구입비,': 1,
#   '재료구입비,': 1,
#   '수용비': 1,
#   '포함)를': 1,
#   '지원\n\n': 1,
#   '시도교육청의': 1,
#   '지원금액': 1,
#   '상이\n\n': 1,
#   '신청한': 1,
#   '달부터': 1,
#   '지원\n\n방법\n\n읍면동': 1,
#   '주민센터(행정복지센터)': 1,
#   '또는': 1,
#   '복지로(httpwww.bokjiro.go.kr),': 1,
#   '교육비원클릭시스템(httponeclick.moe.go.kr)으로': 1,
#   '신청\n\n문의\n\n교육비': 1,
#   '중앙상담센터(15449654)': 1},
#  {'초•중•고': 1,
#   '학생': 1,
#   '교육정보화': 1,
#   '지원(PC,': 1,
#   '인터넷통신비)\n\n대상\n\n기초생활수급자,': 1,
#   '한부모가족,': 1,
#   '차상위계층': 1,
#   '등': 1,
#   '저소득가구의': 1,
#   '초중고학생': 1,
#   '자녀\n\n시도교육청의': 1,
#   '기준에': 2,
#   '따라': 2,
#   '지원대상': 1,
#   '범위': 1,
#   '상이\n\n내용\n\n가구당': 1,
#   '컴퓨터': 1,
#   '1대,': 1,
#   '가구당': 1,
#   '인터넷통신비': 1,
#   '월': 2,
#   '1만': 1,
#   '7,600원(시도별': 1,
#   '유해차단서비스': 1,
#   '1,650원': 1,
#   '지원)': 1,
#   '지원\n\n1세대': 1,
#   '1자녀': 1,
#   '지원으로': 1,
#   '형제자매': 1,
#   '간': 1,
#   '중복지원': 1,
#   '배제\n\n방법\n\n읍면동': 1,
#   '주민센터(행정복지센터)': 1,
#   '또는': 1,
#   '복지로(httpwww.bokjiro.go.kr),': 1,
#   '교육비원클릭시스템(httponeclick.moe.go.kr)으로': 1,
#   '신청\n\n문의\n\n교육비': 1,
#   '중앙상담센터(15449654)': 1},
#  {'국가장학금,': 1,
#   '유형,': 1,
#   '다자녀(세': 1,
#   '자녀': 1,
#   '이상)\n\n대상\n\n국가장학금': 1,
#   'I유형': 1,
#   '\n': 38,
#   '국내': 2,
#   '대학에': 2,
#   '재학': 2,
#   '중인': 2,
#   '학자금지원': 5,
#   '8구간': 2,
#   '이하': 2,
#   '대학생': 2,
#   '국가장학금': 2,
#   'II유형': 1,
#   '9구간': 2,
#   '중': 1,
#   '대학': 1,
#   '자체': 2,
#   '기준에': 1,
#   '따라': 4,
#   '선발': 2,
#   '다자녀': 3,
#   '국가장학금(세자녀': 1,
#   '이상)': 5,
#   '이하,': 1,
#   '다자녀(자녀': 1,
#   '셋': 2,
#   '가구의': 1,
#   '모든': 1,
#   '대학생(미혼에': 1,
#   '한함)\n\n': 1,
#   '유형': 1,
#   '및': 4,
#   '국가장학금은': 1,
#   '성적(B0,': 1,
#   '80100점': 1,
#   '이수학점(직전학기': 1,
#   '12학점': 1,
#   '충족': 1,
#   '필요\n\n': 1,
#   '단,': 2,
#   '기초·차상위': 1,
#   '학생은': 4,
#   'C0(70100점)': 1,
#   '이상': 1,
#   '적용,': 2,
#   '13구간': 1,
#   'C학점': 1,
#   '경고제': 1,
#   '2회': 1,
#   '장애인': 1,
#   '성적기준': 2,
#   '미적용\n\n': 1,
#   '신입생,': 1,
#   '편입생,': 1,
#   '재입학생은': 1,
#   '첫': 1,
#   '학기에': 1,
#   '한해': 1,
#   '미적용\n\n내용\n\n유형,': 1,
#   '': 3,
#   '등록금': 1,
#   '필수': 1,
#   '경비(수업료)를': 1,
#   '초과하지': 1,
#   '않는': 1,
#   '범위': 1,
#   '내에서': 1,
#   '차등': 2,
#   '지원\n\n2023년': 1,
#   '학자금': 1,
#   '지원구간별': 1,
#   '연간': 1,
#   '최대': 1,
#   '지원가능': 1,
#   '금액': 1,
#   '(단위': 1,
#   '만': 1,
#   '원)\n\n유형': 1,
#   '700(둘째전액)': 2,
#   '520': 6,
#   '390': 3,
#   '350': 2,
#   '다자녀(첫째,둘째)': 1,
#   '450': 5,
#   '다자녀(셋째': 1,
#   '전액': 8,
#   '전액\n\n유형': 1,
#   '참여': 1,
#   '대학의': 1,
#   '기준(학자금': 1,
#   '지원': 3,
#   '이하)에': 1,
#   '장학금': 1,
#   '지원\n': 1,
#   '긴급하게': 1,
#   '경제사정이': 1,
#   '곤란하게': 1,
#   '된': 1,
#   '자': 1,
#   '등': 1,
#   '대학이': 1,
#   '필요성이': 1,
#   '있다고': 1,
#   '인정하는': 1,
#   '경우': 1,
#   '10구간도': 1,
#   '가능\n\n방법\n\n한국장학재단': 1,
#   '누리집': 1,
#   '모바일': 1,
#   '앱에서': 1,
#   '신청(httpswww.kosaf.go.kr)\n\n문의\n\n한국장학재단(15992000,': 1,
#   'www.kosaf.go.kr)\n\n알려드립니다\n\n학자금': 1,
#   '지원구간이란\n경제적': 1,
#   '여건에': 1,
#   '범위를': 1,
#   '다르게': 1,
#   '정하기': 1,
#   '위해': 1,
#   '학생': 1,
#   '본인': 1,
#   '가구원의': 1,
#   '소득,': 1,
#   '재산(사회보장': 1,
#   '정보시스템)을': 1,
#   '기준으로': 1,
#   '산정한': 1,
#   '월': 1,
#   '소득': 1,
#   '인정액에': 1,
#   '개인별': 1,
#   '지원구간(110구간)을': 1,
#   '결정하는': 1,
#   '제도입니다.\n형제·자매가': 1,
#   '본인을': 1,
#   '포함해': 1,
#   '이상인': 1,
#   '미혼': 1,
#   '형제·자매': 1,
#   '수에': 1,
#   '따른': 1,
#   '인적': 1,
#   '공제': 1,
#   '적용': 1},
#  {'청소년': 1,
#   '인터넷•스마트폰': 1,
#   '과의존': 5,
#   '예방': 1,
#   '및': 2,
#   '해소': 1,
#   '지원\n\n대상\n\n만': 1,
#   '19세': 1,
#   '미만': 1,
#   '청소년\n\n내용\n\n학령전환기': 1,
#   '청소년(초4,': 1,
#   '중1,': 1,
#   '고1)': 1,
#   '대상': 1,
#   '인터넷·스마트폰': 2,
#   '상담,': 1,
#   '치유': 3,
#   '등': 1,
#   '지원\n\n상담': 1,
#   '치유프로그램': 1,
#   '\n': 5,
#   '': 10,
#   '인터넷치유캠프(11박': 1,
#   '12일)': 1,
#   '가족치유캠프(2박': 1,
#   '3일)': 1,
#   '기초생활수급자,': 1,
#   '차상위,': 1,
#   '한부모,': 1,
#   '다문화': 1,
#   '가족': 1,
#   '등은': 1,
#   '무료로': 1,
#   '참여할': 1,
#   '수': 1,
#   '있고,': 1,
#   '그': 1,
#   '외': 1,
#   '청소년(가족)은': 1,
#   '식비': 1,
#   '일부만': 1,
#   '부담': 1,
#   '국립청소년인터넷드림마을(상설': 1,
#   '인터넷': 1,
#   '전담시설)의': 1,
#   '상설': 1,
#   '프로그램': 1,
#   '(14주': 1,
#   '과정)': 1,
#   '고위험군치료비': 1,
#   '지원': 1,
#   '일반청소년': 1,
#   '최대': 2,
#   '40만': 1,
#   '원': 1,
#   '소득인정액이': 1,
#   '기준': 2,
#   '중위소득': 1,
#   '50%(4인': 1,
#   '270만': 1,
#   '482원)': 1,
#   '이하인': 1,
#   '사회적돌봄대상': 1,
#   '60만': 1,
#   '원\n\n방법\n\n지역별': 1,
#   '청소년상담복지센터를': 1,
#   '통해': 1,
#   '신청': 1,
#   '정도를': 1,
#   '진단평가': 1,
#   '후': 1,
#   '단계별': 1,
#   '지원\n\n문의\n\n전국': 1,
#   '청소년상담복지센터(청소년전화': 1,
#   '1388,': 1,
#   '휴대전화는': 1,
#   '지역번호1388)\n\n한국청소년상담복지개발원(05166231915)\n\n국립청소년인터넷드림마을(0633232285)': 1},
#  {'아동통합서비스': 1,
#   '지원(드림스타트사업)\n\n대상\n\n만': 1,
#   '12세': 1,
#   '이하(초등학생': 1,
#   '이하)의': 1,
#   '취약계층': 1,
#   '아동': 1,
#   '및': 3,
#   '가족(임산부': 1,
#   '포함)\n\n내용\n\n가정방문을': 1,
#   '통해': 1,
#   '조사한': 1,
#   '양육환경·아동발달': 1,
#   '상태를': 1,
#   '기준으로': 1,
#   '아동발달': 1,
#   '영역별': 1,
#   '맞춤형': 1,
#   '통합서비스': 1,
#   '제공\n\n인지·언어,': 1,
#   '신체·건강,': 1,
#   '정서·행동,': 1,
#   '부모': 1,
#   '가족지원\n\n': 1,
#   '건강검진': 1,
#   '예방,': 1,
#   '기초학습지원,': 1,
#   '산전산후관리,': 1,
#   '건강관리,': 1,
#   '치료지원,': 1,
#   '문화체험,': 1,
#   '양육지원': 1,
#   '등\n\n방법\n\n시군구청': 1,
#   '드림스타트,': 1,
#   '읍면동': 1,
#   '주민센터(행정복지센터)': 1,
#   '상담': 1,
#   '후': 1,
#   '신청\n\n문의\n\n보건복지상담센터(129)\n\n주소지': 1,
#   '시군구': 1,
#   '드림스타트\n\n드림스타트': 1,
#   '누리집(httpwww.dreamstart.go.kr)': 1},
#  {'신체적': 1,
#   '배려대상자': 1,
#   '지원\n\n대상\n\n병역판정검사대상자': 1,
#   '중': 1,
#   '악성혈액질환': 1,
#   '등': 1,
#   '중증질환으로': 1,
#   '확진된': 1,
#   '사람\n\n': 1,
#   '대상질환': 1,
#   '': 3,
#   '재생불량성빈혈,': 1,
#   '백혈병,': 1,
#   '골수이형성증후군,': 1,
#   '악성림프종,': 1,
#   '관해': 1,
#   '후': 1,
#   '5년': 1,
#   '이상': 1,
#   '경과한': 1,
#   '혈액암,': 1,
#   '애디슨씨병,': 1,
#   '랑게르한스': 1,
#   '조직구증(전신적': 1,
#   '항암치료자),': 1,
#   '선천성': 1,
#   '면역결핍질환\n\n내용\n\n병역판정검사없이': 1,
#   '서류심사로': 1,
#   '병역': 1,
#   '처분\n\n방법\n\n지방병무청에': 1,
#   '서류': 1,
#   '제출': 1,
#   '병역법': 1,
#   '제64조제1항제1호': 1,
#   '및': 1,
#   '같은': 1,
#   '법': 1,
#   '시행령': 1,
#   '제134조제1항에': 1,
#   '따라': 1,
#   '병역감면(신체등급': 1,
#   '5·6급)': 1,
#   '여부': 1,
#   '결정\n\n': 1,
#   '제출서류': 1,
#   '병역복무변경·면제신청서,': 1,
#   '개인정보제공동의서,': 1,
#   '병무용진단서,': 1,
#   '의무기록지': 1,
#   '등\n\n문의\n\n병무청': 1,
#   '병무민원상담소(15889090)': 1},
#  {'HPV': 5,
#   '국가예방접종': 2,
#   '지원사업\n\n대상\n\n만': 1,
#   '1217세': 1,
#   '여성': 1,
#   '청소년(2005.1.1.2011.12.31.': 1,
#   '출생자)\n\n만': 1,
#   '1826세': 2,
#   '저소득층': 2,
#   '여성(1996.1.1.2004.12.31.': 1,
#   '출생자)\n\n국민기초생활': 1,
#   '보장법상': 2,
#   '기초생활보장수급자': 3,
#   '및': 5,
#   '차상위계층\n\n내용\n\n대상감염병': 1,
#   '': 8,
#   '사람유두종바이러스(HPV)': 1,
#   '감염증\n\n지원백신': 1,
#   '2가(서바릭스),': 1,
#   '4가(가다실)\n\n': 1,
#   '9가는': 1,
#   '지원백신': 1,
#   '아님\n\n지원내용': 1,
#   '예방접종': 2,
#   '총': 1,
#   '23회\n\n첫': 1,
#   '접종': 5,
#   '나이': 1,
#   '과거': 1,
#   '내역에': 1,
#   '따라': 3,
#   '횟수': 1,
#   '상이\n\n': 1,
#   '만': 9,
#   '12세': 1,
#   '대상자(20102011년생)에게는': 1,
#   '시': 1,
#   '건강상담': 1,
#   '함께': 1,
#   '제공\n\n방법\n\n지정의료기관': 1,
#   '보건소': 1,
#   '방문\n\n': 2,
#   '여성은': 1,
#   '차상위계층': 2,
#   '확인서류': 1,
#   '지참': 2,
#   '후': 2,
#   '지정의료기관': 1,
#   '확인': 2,
#   '예방접종도우미': 1,
#   '누리집(httpsnip.kdca.go.kr)\n\n': 1,
#   '지자체': 1,
#   '상황에': 1,
#   '보건소에서': 1,
#   '예방접종이': 1,
#   '불가능할': 1,
#   '수': 1,
#   '있으니': 1,
#   '방문': 1,
#   '전': 1,
#   '확인\n\n문의\n\n질병관리청': 1,
#   '콜센터(1339)\n\n질병관리청': 1,
#   '예방접종관리과(04371983988399)\n\n알려드립니다\n\nHPV': 1,
#   '실시기준(1차': 1,
#   '시기에': 1,
#   '접종횟수가': 1,
#   '달라짐)\n\n만': 1,
#   '1214세': 2,
#   '\n': 46,
#   '2회': 2,
#   'HPV2,': 2,
#   'HPV4': 5,
#   '1차': 3,
#   '612개월': 1,
#   '2차': 3,
#   '1525세': 3,
#   '3회': 6,
#   'HPV2': 3,
#   '1개월': 1,
#   '5개월': 1,
#   '3차': 2,
#   '1526세': 3,
#   '2개월': 1,
#   '4개월': 1,
#   '\n\n국민기초생활': 1,
#   '기준\n\n기초생활보장수급자': 1,
#   '생계급여,': 1,
#   '의료급여,': 1,
#   '주거급여,': 1,
#   '교육급여\n\n차상위계층': 1,
#   '차상위': 4,
#   '장애인,': 1,
#   '본인부담': 1,
#   '경감,': 1,
#   '자활,': 1,
#   '계층': 1,
#   '확인\n': 1,
#   '자격기준에': 1,
#   '대한': 1,
#   '자세한': 1,
#   '내용은': 1,
#   '알려드립니다(본책자': 1,
#   '1213p).를': 1,
#   '참고하시기': 1,
#   '바라며,': 1,
#   '사업': 1,
#   '대상임을': 1,
#   '가능한': 1,
#   '서류를': 1,
#   '접종기관을': 1,
#   '방문하시기': 1,
#   '바랍니다.': 1},
#  {'교육복지': 2,
#   '우선지원사업\n\n대상\n\n교육급여': 1,
#   '수급권자,': 1,
#   '법정': 2,
#   '차상위계층의': 1,
#   '자녀,': 3,
#   '한부모가족의': 1,
#   '북한이탈주민의': 1,
#   '자녀': 1,
#   '및': 1,
#   '다문화가정의': 1,
#   '특수교육대상자,': 1,
#   '그': 1,
#   '밖에': 1,
#   '교육감이': 1,
#   '정하는': 1,
#   '학생\n\n내용\n\n학습,': 1,
#   '문화·체험,': 1,
#   '심리·정서,': 1,
#   '보육,': 1,
#   '복지': 1,
#   '등': 1,
#   '종합적인': 1,
#   '프로그램': 1,
#   '제공\n\n': 1,
#   '지원대상': 1,
#   '학생이': 1,
#   '일정': 1,
#   '수': 1,
#   '이상인': 1,
#   '학교를': 1,
#   '선정해': 1,
#   '지원하며': 1,
#   '선정기준은': 1,
#   '시도교육청에서': 1,
#   '지정\n\n방법\n\n교육감이': 1,
#   '자체': 1,
#   '기준에': 1,
#   '따라': 1,
#   '학교': 1,
#   '지정\n\n문의\n\n각': 1,
#   '시도': 1,
#   '교육청': 1},
#  {'청소년활동': 1,
#   '지원\n\n대상\n\n대한민국': 1,
#   '청소년': 6,
#   '및': 1,
#   '법인·시설·단체\n\n내용\n\n청소년': 1,
#   '어울림마당,': 3,
#   '동아리활동,': 1,
#   '활동': 3,
#   '프로그램을': 1,
#   '공모해': 1,
#   '다양한': 1,
#   '지원\n\n방법\n\n청소년': 1,
#   '동아리활동': 2,
#   '지원': 3,
#   '': 4,
#   '지자체': 2,
#   '심사를': 1,
#   '통해': 2,
#   '선정\n\n청소년': 1,
#   '프로그램': 3,
#   '공모': 2,
#   '심사위원회를': 1,
#   '구성하여': 1,
#   '운영': 1,
#   '기관(단체)': 1,
#   '선정\n\n문의\n\n청소년': 1,
#   '각': 1,
#   '부서\n\n청소년': 1,
#   '한국청소년활동진흥원(023302818)\n\n알려드립니다\n\n국립수련시설에서': 1,
#   '특별한': 1,
#   '활동을': 1,
#   '누려보세요.\n\n한국청소년활동진흥원': 1,
#   '누리집': 1,
#   '국립수련시설': 1,
#   '이용신청을': 1,
#   '국립중앙청소년수련원,': 1,
#   '국립평창청소년수련원,': 1,
#   '국립청소년우주센터': 1,
#   '등': 1,
#   '수련시설에서': 1,
#   '진행하는': 1,
#   '특성화캠프,': 1,
#   '가족캠프': 1,
#   '등의': 1,
#   '참가': 1,
#   '신청을': 1,
#   '할': 1,
#   '수': 1,
#   '있습니다.': 1},
#  {'인문100년': 1,
#   '장학금\n\n대상\n\n국내': 1,
#   '4년제': 1,
#   '대학의': 1,
#   '인문사회계열': 1,
#   '학과(부)': 1,
#   '1,': 1,
#   '3학년': 2,
#   '재학생을': 1,
#   '대상으로': 1,
#   '1학년': 1,
#   '전공탐색': 1,
#   '(I,II)유형과': 1,
#   '전공확립(I,II)유형으로': 1,
#   '구분하여': 1,
#   '지원': 3,
#   '대상': 1,
#   '선발\n\n내용\n\n유형(등록금)': 1,
#   '\n': 13,
#   '장학생': 2,
#   '선정': 2,
#   '후': 2,
#   '매': 2,
#   '학기별': 2,
#   '등록금': 3,
#   '전액(해당학기': 2,
#   '계속지원': 2,
#   '기준': 2,
#   '충족': 2,
#   '시)': 2,
#   '유형(생활비)': 2,
#   '공통지원': 1,
#   '': 11,
#   '학기당': 3,
#   '250만': 3,
#   '원': 3,
#   '기초생활수급자': 2,
#   '추가지원': 2,
#   '장학생으로': 2,
#   '확정된': 2,
#   '연도의': 2,
#   '지원내용': 2,
#   '및': 2,
#   '금액': 2,
#   '적용(소급적용': 2,
#   '불가)': 2,
#   '유형(등록금)': 1,
#   '계속지원기준': 1,
#   '성적기준': 1,
#   '직전학기': 3,
#   '백분위': 2,
#   '90점': 1,
#   '이상': 2,
#   '또는': 1,
#   '평점': 1,
#   '3.6점': 1,
#   '이상4.5점': 1,
#   '만점(3.4점': 1,
#   '이상4.3점': 1,
#   '만점)': 1,
#   '생활비': 1,
#   '92점': 1,
#   '최소이수학점': 1,
#   '12학점': 1,
#   '이상\n\n': 1,
#   '·유형': 1,
#   '내용은': 1,
#   '2023년도': 1,
#   '신규장학생': 1,
#   '기준\n\n방법\n\n한국장학재단': 1,
#   '누리집(httpswww.kosaf.go.kr)에서': 1,
#   '신청\n\n문의\n\n한국장학재단(15992290,': 1,
#   'www.kosaf.go.kr)': 1},
#  {'학교': 3,
#   '밖': 4,
#   '청소년': 2,
#   '건강검진\n\n대상\n\n9세': 1,
#   '이상': 2,
#   '18세': 1,
#   '이하': 1,
#   '청소년\n': 1,
#   '': 6,
#   '19세': 1,
#   '청소년은': 1,
#   '건강검진은': 1,
#   '가능하나,': 1,
#   '다른': 1,
#   '국가건강검진과': 1,
#   '중복': 1,
#   '지원': 1,
#   '불가\n\n내용\n\n학교': 1,
#   '건강검진': 1,
#   '비용': 1,
#   '전액': 1,
#   '지원(본인부담': 1,
#   '없음)\n\n기본': 1,
#   '건강상담(문진': 2,
#   '등)': 2,
#   '\n': 11,
#   '요검사,': 1,
#   '혈액검사': 1,
#   ',': 3,
#   'B형': 1,
#   '간염검사': 2,
#   'C형': 2,
#   '구강검진,': 2,
#   '흉부': 2,
#   '방사선': 2,
#   '촬영': 2,
#   '기본': 1,
#   '요단백,': 1,
#   '요잠혈,': 1,
#   '혈색소,': 1,
#   '혈당,': 1,
#   '총콜레스테롤,': 2,
#   'AST,': 1,
#   'ALT,': 1,
#   'B형간염표면항원,': 1,
#   'B형간염표면항체,': 1,
#   '간염항체,': 1,
#   '선택': 1,
#   '(상담)': 2,
#   '매독,': 1,
#   '후천성면역결핍증(HIV),': 1,
#   '클라미디아,': 1,
#   '클라미디아임질(성매개질환)': 1,
#   '확진': 1,
#   '혈압측정,': 1,
#   '공복혈당,': 1,
#   '요단백,요잠혈,': 1,
#   'HDL,': 1,
#   'LDL,': 1,
#   '중성지방,': 1,
#   'C형간염': 1,
#   '정밀검사,': 1,
#   '매독정밀검사\n\n': 1,
#   '체질량지수가': 1,
#   '백분위수': 1,
#   '도표': 1,
#   '95': 1,
#   '또는': 2,
#   'BMI': 1,
#   '25': 1,
#   '이상인': 1,
#   '경우에': 1,
#   '한해': 1,
#   '실시\n\n': 2,
#   '여성의': 1,
#   '경우만': 1,
#   '최초': 1,
#   '검진': 1,
#   '시행': 1,
#   '시에만': 1,
#   '실시(검진': 1,
#   '주기': 1,
#   '3년': 1,
#   '도래': 1,
#   '후부터는': 1,
#   '미실시)\n\n방법\n\n건강검진': 1,
#   '신청서를': 1,
#   '작성하여': 1,
#   '학교밖청소년지원센터(이하': 1,
#   '꿈드림센터)를': 1,
#   '방문,': 1,
#   '우편': 1,
#   '이메일': 2,
#   '제출': 2,
#   '시에는': 1,
#   '반드시': 1,
#   '해당': 1,
#   '꿈드림센터와': 1,
#   '협의': 1,
#   '후': 1,
#   '제출\n\n문의\n\n지역별': 1,
#   '꿈드림센터\n': 1,
#   '꿈드림센터': 2,
#   '누리집(www.kdream.or.kr)': 1,
#   '검색을': 1,
#   '통해': 1,
#   '지역별': 1,
#   '확인\n\n청소년전화(1388,': 1,
#   '휴대전화는': 1,
#   '지역번호1388)': 1},
#  {'우수고등학생': 2,
#   '해외유학': 2,
#   '장학금(드림장학금)\n\n대상\n\n국내': 1,
#   '고교': 2,
#   '2,': 1,
#   '3학년': 1,
#   '재학자': 1,
#   '중': 4,
#   '해외대학': 1,
#   '입학을': 1,
#   '희망하는': 1,
#   '저소득층(신청일': 1,
#   '기준': 1,
#   '기초생활수급자,': 1,
#   '차상위계층)': 1,
#   '성적': 1,
#   '우수': 1,
#   '학생\n\n2024년': 1,
#   '2월': 2,
#   '또는': 2,
#   '2025년': 1,
#   '졸업예정자\n\n': 1,
#   '선발예정인원': 1,
#   '30명': 1,
#   '내외(고2': 1,
#   '50%': 2,
#   '내외,': 1,
#   '고3': 2,
#   '내외': 1,
#   '선발,': 1,
#   '마이스터고': 1,
#   '및': 2,
#   '특성화고': 1,
#   '5명': 1,
#   '이내': 2,
#   '선발)\n\n학생': 1,
#   '온라인': 1,
#   '신청자\n\n고교': 1,
#   '재학': 1,
#   '직전학기까지': 1,
#   '전체학기': 1,
#   '이수한': 1,
#   '국어,': 1,
#   '영어,': 1,
#   '수학,': 1,
#   '과학,': 1,
#   '한국사,': 1,
#   '사회,': 1,
#   '전문교과': 1,
#   '과목': 1,
#   '석차': 1,
#   '2등급': 1,
#   '성취도(학점)': 1,
#   'A': 1,
#   '이상인': 1,
#   '과목의': 1,
#   '이수단위': 1,
#   '합계가': 1,
#   '24단위(고3)12단위(고2)': 1,
#   '이상\n\n내용\n\n유학준비생(국내장학생)': 1,
#   '\n': 4,
#   '': 23,
#   '지원대상': 2,
#   '신규': 1,
#   '장학생으로': 1,
#   '선발(서류,': 1,
#   '인적성': 1,
#   '검사,': 1,
#   '면접)된': 1,
#   '학생': 1,
#   '지원내역': 2,
#   '학업장려비': 1,
#   '지원(고2': 1,
#   '월': 2,
#   '50만': 1,
#   '원,': 1,
#   '70만': 1,
#   '원)': 1,
#   '지원기간': 2,
#   '선발': 1,
#   '익월부터': 1,
#   '졸업': 1,
#   '시(2월': 1,
#   '말)까지': 1,
#   '지원': 1,
#   '지급절차': 1,
#   '월별': 1,
#   '학업보고서': 1,
#   '제출,': 1,
#   '학업': 1,
#   '보고서': 1,
#   '심사': 1,
#   '승인,': 1,
#   '학생계좌로': 1,
#   '개별': 1,
#   '지급': 1,
#   '유학생(해외장학생)': 1,
#   '유학준비생(국내장학생)': 1,
#   '해외대학에': 1,
#   '최종': 2,
#   '합격하여': 1,
#   '진학이': 1,
#   '결정(예정)된': 1,
#   '자': 1,
#   '세계': 2,
#   '대학': 1,
#   '순위': 2,
#   '400위(또는': 1,
#   '전공': 1,
#   '50위)': 1,
#   '등': 1,
#   '진학': 1,
#   '가능': 1,
#   '대학에': 1,
#   '합격한': 1,
#   '경우': 1,
#   '유학생': 1,
#   '전환': 1,
#   '연간': 1,
#   '최대': 1,
#   '6만': 1,
#   'USD(학비체재비),': 1,
#   '항공료': 1,
#   '별도': 1,
#   '세부': 1,
#   '내용은': 1,
#   '한국장학재단': 1,
#   '누리집': 2,
#   '참고': 1,
#   '입학': 1,
#   '학기부터': 1,
#   '졸업시까지': 1,
#   '정규학기': 1,
#   '내에서': 1,
#   '지원\n\n방법\n\n한국장학재단': 1,
#   '누리집에서': 1,
#   '신청\n\n한국장학재단': 1,
#   '장학금': 1,
#   '국가우수장학금': 1,
#   '장학금(드림장학금)\n\n문의\n\n한국장학재단(15992290,': 1,
#   'www.kosaf.go.kr)': 1},
#  {'청소년동반자': 1,
#   '프로그램\n\n대상\n\n다양한': 1,
#   '위기를': 1,
#   '겪고': 1,
#   '있는': 1,
#   '만': 1,
#   '924세': 1,
#   '청소년\n\n': 1,
#   '우선지원대상': 1,
#   '': 1,
#   '우울증,': 1,
#   '자살위험,': 1,
#   '가출,': 1,
#   '비행,': 1,
#   '인터넷': 1,
#   '중독,': 1,
#   '폭력(성·학교·가정)': 1,
#   '피해,': 1,
#   '학업중단': 1,
#   '청소년': 1,
#   '등\n\n내용\n\n청소년': 1,
#   '상담': 1,
#   '전문가가': 1,
#   '위기상황': 1,
#   '청소년을': 1,
#   '직접': 1,
#   '찾아가': 1,
#   '상담하고,': 1,
#   '청소년의': 1,
#   '문제': 1,
#   '유형과': 1,
#   '개별': 1,
#   '특성을': 1,
#   '고려한': 1,
#   '서비스': 1,
#   '제공\n\n방법\n\n청소년상담전화': 1,
#   '또는': 1,
#   '청소년상담복지센터': 1,
#   '방문': 1,
#   '상담\n\n문의\n\n청소년전화(1388,': 1,
#   '휴대전화는': 1,
#   '국번1388)\n\n문자(1388),': 1,
#   '카카오톡·페이스북(청소년상담1388),': 1,
#   '채팅': 1,
#   '및': 1,
#   '게시판': 1,
#   '상담(www.cyber1388.kr)': 1},
#  {'지역사회': 2,
#   '청소년': 2,
#   '통합지원체계(청소년안전망)\n\n대상\n\n만': 1,
#   '9세24세': 1,
#   '위기청소년': 2,
#   '및': 6,
#   '가족\n\n내용\n\n위기청소년이': 1,
#   '가정,': 1,
#   '학교': 1,
#   '사회로': 1,
#   '안전하게': 1,
#   '돌아갈': 1,
#   '수': 1,
#   '있도록': 1,
#   '상담·보호·교육·자립': 1,
#   '등': 2,
#   '맞춤형': 2,
#   '서비스': 2,
#   '제공(청소년상담복지센터와': 1,
#   '자원': 1,
#   '연계·협력)\n': 1,
#   '지역사회청소년': 1,
#   '통합지원체계(청소년안전망)': 1,
#   '': 1,
#   '통합지원': 1,
#   '연계협력,': 1,
#   '상담': 1,
#   '활동지원,': 1,
#   '청소년전화': 1,
#   '1388': 1,
#   '운영,': 1,
#   '긴급구조,': 1,
#   '일시보호,': 1,
#   '교육': 1,
#   '자립': 1,
#   '제공\n\n방법\n\n청소년상담복지센터': 1,
#   '전화': 1,
#   '또는': 1,
#   '방문\n\n문의\n\n청소년전화(1388,': 1,
#   '휴대전화는': 1,
#   '국번1388)\n\n문자(1388),': 1,
#   '카카오톡·페이스북(청소년상담1388)\n\n채팅': 1,
#   '게시판': 1,
#   '상담(www.cyber1388.kr)': 1},
#  {'청소년치료재활센터(국립중앙청소년디딤센터,': 1,
#   '국립대구청소년디딤센터)운영\n\n대상\n\n정서·행동에': 1,
#   '어려움이': 1,
#   '있는': 1,
#   '청소년(만': 1,
#   '9세18세)\n\n우울증,': 1,
#   '불안장애,': 1,
#   '학교부적응,': 1,
#   '주의력결핍과잉행동장애(ADHD),': 1,
#   '학대': 1,
#   '및': 1,
#   '학교폭력': 1,
#   '피해': 1,
#   '청소년': 1,
#   '등\n\n내용\n\n정서·행동영역에서의': 1,
#   '어려움': 1,
#   '정도에': 1,
#   '따라': 1,
#   '디딤과정(4개월),': 1,
#   '오름과정(1개월),': 1,
#   '단기캠프': 1,
#   '(11박12일)': 1,
#   '등': 1,
#   '제공\n\n상담·치료(정신의학적': 1,
#   '상담),': 1,
#   '보호(거주형': 1,
#   '보호시설),': 1,
#   '교육(검정고시': 1,
#   '지원),': 1,
#   '자립지도': 1,
#   '(직업교육,': 1,
#   '체험활동': 1,
#   '등)': 1,
#   '지원\n\n방법\n\n누구나': 1,
#   '개별': 1,
#   '신청': 1,
#   '가능,': 1,
#   '또는': 1,
#   '한국청소년상담복지개발원,': 1,
#   '청소년상담복지센터,': 1,
#   '학교밖': 1,
#   '청소년지원센터,': 1,
#   '청소년쉼터,': 1,
#   '교육청,': 1,
#   '학교,': 1,
#   '위(Wee)센터,': 1,
#   '가족센터,': 1,
#   '아동복지시설': 1,
#   '등을': 1,
#   '통해': 2,
#   '신청\n\n': 1,
#   '서류심사와': 1,
#   '심층면접,': 1,
#   '입·퇴교판정위원회': 1,
#   '심사를': 1,
#   '최종': 1,
#   '선정\n\n문의\n\n국립중앙청소년디딤센터(www.nyhc.or.kr),': 1,
#   '0313331900\n\n국립대구청소년디딤센터(www.youthfly.or.kr),': 1,
#   '0536656900\n\n자주': 1,
#   '하는': 1,
#   '질문\n\n참가비용은': 1,
#   '어떻게': 1,
#   '되나요': 1,
#   '저소득층에게는': 1,
#   '어떤': 1,
#   '혜택이': 1,
#   '있나요\n\n기초생활보장수급자·차상위계층·한부모가족': 1,
#   '지원대상자': 1,
#   '자녀는': 2,
#   '무료로': 1,
#   '지원받을': 1,
#   '수': 1,
#   '있고,': 1,
#   '이': 1,
#   '외': 1,
#   '일반가정': 1,
#   '장기과정(디딤과정,': 1,
#   '오름과정)은': 1,
#   '월': 1,
#   '30만': 1,
#   '원,': 1,
#   '단기과정(11박': 1,
#   '12일)은': 1,
#   '10만': 1,
#   '원의': 1,
#   '참가비를': 1,
#   '납부해야': 1,
#   '합니다.': 1},
#  {'이주배경청소년': 2,
#   '지원\n\n대상\n\n924세': 1,
#   '이주배경': 1,
#   '청소년(다문화가정': 1,
#   '청소년,': 3,
#   '중도입국': 1,
#   '외국인가정': 1,
#   '북한이탈': 1,
#   '청소년': 1,
#   '등)\n\n내용\n\n레인보우스쿨': 1,
#   '\n': 7,
#   '': 14,
#   '교육대상': 1,
#   '한국어': 2,
#   '및': 5,
#   '진로교육이': 1,
#   '필요한': 1,
#   '운영기관': 1,
#   '전국': 1,
#   '26개': 1,
#   '레인보우스쿨': 1,
#   '운영유형': 1,
#   '통합형': 1,
#   '단계별': 1,
#   '교육,': 2,
#   '진로교육,': 1,
#   '자격증': 1,
#   '사회적응': 2,
#   '프로그램': 1,
#   '등': 2,
#   '북한이탈청소년': 1,
#   '사회적응지원': 1,
#   '탈북청소년': 1,
#   '비교문화': 1,
#   '체험학습(생활': 1,
#   '문화': 1,
#   '체험': 1,
#   '등),': 1,
#   '사회적응을': 1,
#   '위한': 2,
#   '다각적': 1,
#   '교육(성,': 1,
#   '인권,': 1,
#   '진로,': 1,
#   '건강': 1,
#   '등)': 2,
#   '상담지원': 1,
#   '상담환경': 1,
#   '조성': 1,
#   '이주배경청소년의': 2,
#   '심리적': 1,
#   '어려움': 1,
#   '해소': 1,
#   '한국': 1,
#   '생활': 1,
#   '정착을': 1,
#   '상담': 1,
#   '서비스': 1,
#   '지원(대면,': 1,
#   '비대면,': 1,
#   '온라인': 2,
#   '상담통역이': 1,
#   '가능한': 1,
#   '상담통역지원사(중국어,': 1,
#   '베트남어,': 1,
#   '러시아어,': 1,
#   '몽골어)': 1,
#   '양성': 1,
#   '운영': 1,
#   '대인관계,': 1,
#   '학업적응': 1,
#   '상태를': 1,
#   '평가할': 1,
#   '수': 2,
#   '있는': 1,
#   '검사': 1,
#   '운영\n\n방법\n\n레인보우스쿨': 1,
#   '신청': 1,
#   '이주배경청소년지원재단에': 2,
#   '문의(전화': 1,
#   '또는': 1,
#   '방문)\n\n상담신청': 1,
#   '(기관)': 1,
#   '의뢰서발송,': 1,
#   '(대상자': 1,
#   '직접': 1,
#   '신청)': 1,
#   '재단': 1,
#   '누리집': 1,
#   '상담신청\n\n문의\n\n이주배경청소년지원재단(httpwww.rainbowyouth.or.kr)': 1,
#   '(027337587)\n\n알려드립니다\n\n레인보우스쿨은': 1,
#   '몇': 1,
#   '군데가': 1,
#   '운영되고': 1,
#   '있나요\n\n전국': 1,
#   '26개소를': 1,
#   '운영하고': 1,
#   '있습니다.(매년': 1,
#   '공모를': 1,
#   '통해': 1,
#   '선정)': 1,
#   '문의하시면': 1,
#   '가까운': 1,
#   '기관을': 1,
#   '안내받으실': 1,
#   '있습니다.': 1},
#  {'농촌출신': 1,
#   '대학생': 3,
#   '학자금': 1,
#   '융자사업\n\n대상\n\n농어촌지역에': 1,
#   '주민등록': 1,
#   '주소를': 1,
#   '두고': 1,
#   '6개월(180일)': 1,
#   '이상': 2,
#   '거주하고': 1,
#   '있거나': 1,
#   '농어업에': 4,
#   '종사하고': 1,
#   '있는': 1,
#   '학부모(보호자)의': 3,
#   '자녀(대학생)': 3,
#   '또는': 1,
#   '종사하는': 3,
#   '본인\n\n직전학기': 1,
#   '성적': 1,
#   '70점100점(C학점)': 1,
#   '이상,': 1,
#   '12학점': 2,
#   '이수한': 1,
#   '대학생\n\n': 1,
#   '소속대학의': 1,
#   '최저': 1,
#   '이수학점이': 1,
#   '미만인': 1,
#   '경우는': 1,
#   '대학': 1,
#   '학사규정에': 1,
#   '의함\n\n': 1,
#   '신입생군(신입생,': 1,
#   '편입생,': 1,
#   '재입학생),': 1,
#   '장애인인': 1,
#   '경우': 2,
#   '성적,': 1,
#   '이수학점': 2,
#   '기준': 2,
#   '적용': 2,
#   '제외\n\n': 1,
#   '졸업': 1,
#   '학년': 1,
#   '학생의': 1,
#   '제외\n\n순위별': 1,
#   '세부': 1,
#   '자격': 1,
#   '요건\n\n1순위': 1,
#   '\n': 7,
#   '': 5,
#   '본인': 1,
#   '기초생활수급자,': 1,
#   '차상위계층,': 1,
#   '장애인,': 1,
#   '다문화가족,': 1,
#   '다자녀가구(3자녀': 1,
#   '이상)': 1,
#   '2순위': 1,
#   '농어촌지역에': 1,
#   '거주하는': 1,
#   '3순위': 1,
#   '특별승인자\n\n내용\n\n당해': 1,
#   '학기': 2,
#   '대학이': 1,
#   '통보한': 1,
#   '등록금(입학금,': 1,
#   '수업료': 1,
#   '등)': 1,
#   '범위': 1,
#   '내': 1,
#   '전액': 1,
#   '무이자': 1,
#   '대출\n\n방법\n\n한국장학재단': 1,
#   '누리집(httpswww.kosaf.go.kr)에서': 1,
#   '신청\n\n문의\n\n한국장학재단(15992290,': 1,
#   'www.kosaf.go.kr)\n\n자주': 1,
#   '하는': 1,
#   '질문\n\n농촌학자금융자를': 1,
#   '신청하려고': 1,
#   '합니다.': 1,
#   '나이제한이': 1,
#   '있나요\n\n농촌학자금융자는': 1,
#   '나이제한은': 1,
#   '없으며,': 1,
#   '대한민국': 1,
#   '국적인': 1,
#   '대학(교)': 1,
#   '학부생이면': 1,
#   '됩니다\n\n농촌학자금융자는': 1,
#   '생활비': 2,
#   '대출은': 2,
#   '없나요\n\n농촌학자금융자는': 1,
#   '당해': 1,
#   '등록금': 1,
#   '대출로만': 1,
#   '이용가능하며,': 1,
#   '한국장학재단에서': 1,
#   '운영하는': 1,
#   '타': 1,
#   '학자금대출을': 1,
#   '이용하시면': 1,
#   '됩니다.': 1},
#  {'중소기업': 1,
#   '취업연계': 1,
#   '장학사업(희망사다리유형)\n\n대상\n\n중소기업': 1,
#   '취업': 1,
#   '및': 2,
#   '창업을': 1,
#   '희망하는': 1,
#   '학부': 1,
#   '재학생\n': 1,
#   '일반대': 1,
#   '3학년': 1,
#   '이상,': 1,
#   '전문대': 1,
#   '2학년': 1,
#   '이상.': 1,
#   '단,': 1,
#   '원격대학(방송통신대학': 1,
#   '사이버대학': 1,
#   '등)은': 1,
#   '제외\n': 1,
#   '계약학과는': 2,
#   '지원대상에서': 1,
#   '제외되나,': 1,
#   '조기취업형': 1,
#   '1학년에': 1,
#   '한해': 1,
#   '지원': 1,
#   '가능\n': 1,
#   '': 4,
#   '(성적기준)': 1,
#   '직전학기': 1,
#   '대학별': 1,
#   '최소': 2,
#   '이수학점': 2,
# ...
#   '법정대리인이': 1,
#   '읍면동': 2,
#   '주민센터(행정복지센터)에': 1,
#   '신청·접수': 1,
#   '': 2,
#   '상담': 1,
#   '욕구조사(읍면동': 1,
#   '주민센터(행정복지센터)),': 1,
#   '소득조사(시군구)': 1,
#   '이용자': 1,
#   '선정·통지\n\n': 1,
#   '제공기관은': 1,
#   '관할': 1,
#   '시군구,': 1,
#   '전자바우처포털(www.socialservice.or.kr)에서': 1,
#   '확인': 1,
#   '가능\n\n문의\n\n보건복지상담센터(129)\n\n': 1,
#   '지역별': 1,
#   '사업이': 1,
#   '상이하므로': 1,
#   '주민센터(행정복지센터)': 1,
#   '시군구청에': 1,
#   '사전': 1,
#   '문의': 1,
#   '필요': 1},
#  {'결혼이민자': 2,
#   '통번역서비스\n\n대상\n\n다문화가족,': 1,
#   '관련기관\n\n내용\n\n한국말이': 1,
#   '서툰': 1,
#   '결혼이민자의': 1,
#   '가족·사회생활에': 1,
#   '필요한': 1,
#   '의사소통을': 1,
#   '지원하기': 1,
#   '위한': 1,
#   '통·번역': 1,
#   '서비스': 1,
#   '제공\n\n제공언어': 1,
#   '': 1,
#   '주요': 1,
#   '출신국': 1,
#   '언어\n베트남어,': 1,
#   '중국어,': 1,
#   '필리핀어(영어,': 1,
#   '타갈로그어),': 1,
#   '몽골어,': 1,
#   '태국어,': 1,
#   '러시아어,': 1,
#   '캄보디아어,': 1,
#   '일본어,': 1,
#   '네팔어': 1,
#   '등\n\n체류': 1,
#   '관련': 1,
#   '정보': 1,
#   '제공,': 1,
#   '임신': 1,
#   '및': 2,
#   '출산과': 1,
#   '양육': 1,
#   '등': 1,
#   '생활정보': 1,
#   '안내': 1,
#   '상담': 1,
#   '지원\n\n방법\n\n다문화가족지원센터에': 1,
#   '신청\n': 1,
#   '다누리포털을': 1,
#   '통해': 1,
#   '인근': 1,
#   '센터': 1,
#   '확인\n\n문의\n\n다누리콜센터(15771366)\n\n다누리': 1,
#   '누리집\n\n다누리': 1,
#   '앱': 1},
#  {'진폐근로자': 1,
#   '보호\n\n대상\n\n8대': 1,
#   '광업': 1,
#   '분진작업에': 1,
#   '1년': 1,
#   '이상': 1,
#   '종사한': 1,
#   '진폐': 2,
#   '장해': 2,
#   '판정': 1,
#   '근로자\n\n내용\n\n진폐': 1,
#   '건강진단\n\n진폐건강진단': 1,
#   '비용': 1,
#   '실비': 2,
#   '지원\n\n정밀건강진단': 1,
#   '실시자에': 1,
#   '대해': 1,
#   '입원': 1,
#   '1일당': 1,
#   '5만': 1,
#   '원': 1,
#   '진단': 1,
#   '수당': 1,
#   '및': 1,
#   '병원': 1,
#   '통원료': 1,
#   '지급\n\n진폐': 1,
#   '위로금\n\n장해등급에': 1,
#   '따라': 1,
#   '평균임금의': 1,
#   '2151,040일분의': 1,
#   '재해': 1,
#   '위로금': 1,
#   '지급\n\n2010년': 1,
#   '11월': 1,
#   '21일': 1,
#   '이전': 1,
#   '진폐로': 1,
#   '장해판정': 1,
#   '받은': 1,
#   '경우': 1,
#   '산재보험': 1,
#   '일시금': 1,
#   '또는': 1,
#   '유족일시금의': 1,
#   '60%': 1,
#   '지급\n\n진폐근로자': 1,
#   '자녀': 1,
#   '장학금\n\n진폐': 1,
#   '근로자': 1,
#   '자녀의': 1,
#   '중·고등학교': 1,
#   '학자금': 1,
#   '지급\n\n방법\n\n근로복지공단에': 1,
#   '신청\n\n문의\n\n근로복지공단': 1,
#   '15880075': 1},
#  {'농어업인': 1,
#   '연금보험료': 1,
#   '지원\n\n대상\n\n농어업인': 1,
#   '중': 1,
#   '국민연금': 2,
#   '지역가입자': 1,
#   '및': 1,
#   '지역임의계속가입자\n\n내용\n\n본인부담': 1,
#   '보험료의': 1,
#   '최대': 2,
#   '50%까지': 1,
#   '지원(월': 1,
#   '4만': 1,
#   '6,350원)\n\n방법\n\n관할': 1,
#   '국민연금공단': 1,
#   '지사에': 1,
#   '신청\n\n문의\n\n국민연금공단(1355)': 1},
#  {'결혼이민여성': 1,
#   '직업교육훈련\n\n대상\n\n여성새로일하기센터에': 1,
#   '구직': 1,
#   '등록한': 1,
#   '결혼이민여성\n\n내용\n\n결혼이민여성의': 1,
#   '직무역량': 1,
#   '향상을': 1,
#   '위한': 1,
#   '직업교육': 1,
#   '제공\n\n방법\n\n거주': 1,
#   '지역': 1,
#   '여성새로일하기센터에': 1,
#   '신청\n\n문의\n\n여성새로일하기센터(15441199)\n\nsaeil.mogef.go.kr': 1},
#  {'북한이탈주민': 1,
#   '사회보장': 1,
#   '지원\n\n대상\n\n생활이': 1,
#   '어려운': 1,
#   '북한이탈주민\n\n내용\n\n생계급여': 1,
#   '및': 1,
#   '의료급여': 1,
#   '특례\n\n최초': 1,
#   '거주지': 2,
#   '전입일': 1,
#   '이후': 1,
#   '5년까지': 1,
#   '특례': 1,
#   '적용\n\n근로무능력가구일': 1,
#   '경우': 2,
#   '가구원수에': 1,
#   '1명을': 1,
#   '추가한': 1,
#   '소득인정액': 1,
#   '기준': 2,
#   '적용,': 1,
#   '부양의무자': 1,
#   '미적용\n\n근로능력가구일': 1,
#   '최초': 1,
#   '전입': 1,
#   '후': 1,
#   '6개월간은': 1,
#   '자활사업참여': 1,
#   '의무': 1,
#   '조건': 1,
#   '제시를': 1,
#   '유예\n\n국민연금': 1,
#   '특례\n\n보호결정': 1,
#   '당시': 1,
#   '만': 1,
#   '5060세': 1,
#   '미만인': 1,
#   '자가': 1,
#   '가입': 1,
#   '기간': 1,
#   '5년을': 1,
#   '채우면': 1,
#   '노령연금': 1,
#   '수급\n\n방법\n\n읍면동': 1,
#   '주민센터(행정복지센터)': 1,
#   '또는': 1,
#   '국민연금공단에': 1,
#   '신청\n\n문의\n\n생계급여·의료급여': 1,
#   '읍면동': 1,
#   '주민센터(행정복지센터)\n\n연금특례': 1,
#   '국민연금공단(1355)\n\n북한이탈주민의': 1,
#   '안정적': 1,
#   '국내': 1,
#   '정착을': 1,
#   '지원하기': 1,
#   '위해': 1,
#   '다양한': 1,
#   '서비스를': 1,
#   '제공합니다.': 1},
#  {'석면피해자': 1,
#   '지원(석면피해': 1,
#   '구제급여)\n\n대상\n\n석면광산': 1,
#   '또는': 1,
#   '석면공장': 1,
#   '주변에': 1,
#   '장기간': 1,
#   '거주하는': 1,
#   '등의': 1,
#   '사유로': 1,
#   '석면질병(원발성': 1,
#   '악성중피종,': 1,
#   '원발성': 2,
#   '폐암,': 1,
#   '석면폐증,': 1,
#   '미만성': 2,
#   '흉막비후)에': 1,
#   '걸려': 1,
#   '건강상': 1,
#   '피해를': 1,
#   '입은': 1,
#   '사람': 1,
#   '및': 1,
#   '그': 1,
#   '유족\n\n': 1,
#   '단,': 1,
#   '산업재해보상': 1,
#   '급여': 1,
#   '등을': 1,
#   '받을': 1,
#   '수': 2,
#   '있는': 1,
#   '자는': 1,
#   '적용대상에서': 1,
#   '제외\n\n내용\n\n원발성': 1,
#   '악성중피종': 1,
#   '\n': 33,
#   '167만': 2,
#   '1,670원': 2,
#   '4,650만': 2,
#   '2,550원': 2,
#   '310만': 6,
#   '170원': 5,
#   '석면질병치료비(단,': 1,
#   '본인일부부담금만': 1,
#   '지원되며,': 1,
#   '연간': 1,
#   '본인부담상한액을': 1,
#   '초과할': 1,
#   '없음)': 1,
#   '폐암': 1,
#   '흉막비후': 1,
#   '118만': 2,
#   '2,000원': 2,
#   '2,325만': 2,
#   '1,270원': 2,
#   '석면폐증': 3,
#   '1급': 1,
#   '2급': 1,
#   '78만': 1,
#   '8,000원': 1,
#   '1,550만': 1,
#   '850원': 1,
#   '3급': 1,
#   '39만': 1,
#   '4,000원': 1,
#   '775만': 1,
#   '420원': 1,
#   '170원\n\n방법\n\n시군구청(환경업무': 1,
#   '담당과)에': 1,
#   '문의': 1,
#   '후': 1,
#   '신청\n\n문의\n\n한국환경산업기술원': 1,
#   '석면피해구제실': 1,
#   '': 1,
#   '18337690\n\n석면피해구제': 1,
#   '누리집': 1},
#  {'긴급복지': 2,
#   '지원제도\n\n대상\n\n대한민국': 1,
#   '국민과': 1,
#   '혼인': 1,
#   '중인': 1,
#   '사람\n\n대한민국': 1,
#   '국민인': 1,
#   '배우자와': 1,
#   '이혼': 1,
#   '또는': 2,
#   '사망으로': 1,
#   '대한민국': 1,
#   '국적을': 1,
#   '가진': 1,
#   '부모·조부모,': 1,
#   '자녀·손자녀를': 1,
#   '돌보고': 1,
#   '있는': 1,
#   '사람\n\n난민으로': 1,
#   '인정된': 1,
#   '사람\n\n본인의': 1,
#   '귀책사유': 1,
#   '없이': 1,
#   '화재,': 1,
#   '범죄,': 1,
#   '천재지변으로': 1,
#   '피해를': 1,
#   '입은': 1,
#   '사람\n\n내용\n\n생계지원,': 1,
#   '의료지원,': 1,
#   '주거지원,': 1,
#   '사회복지시설': 1,
#   '이용지원,': 1,
#   '교육지원,': 1,
#   '그': 1,
#   '밖의': 1,
#   '지원(동절기': 1,
#   '연료비,': 1,
#   '해산비,': 1,
#   '장제비,': 1,
#   '전기요금)\n': 1,
#   '지원제도': 1,
#   '참조': 1,
#   '(본': 1,
#   '책자': 1,
#   '20p)\n\n방법\n\n시·군·구청,': 1,
#   '읍·면·동': 1,
#   '주민센터(행정복지센터)': 1,
#   '및': 1,
#   '보건복지상담센터(129)에': 1,
#   '지원요청': 1,
#   '신고\n\n문의\n\n보건복지상담센터(129)': 1},
#  {'농촌': 1,
#   '보육': 1,
#   '교사': 1,
#   '특별근무수당\n\n대상\n\n농촌지역': 1,
#   '소재': 1,
#   '어린이집': 1,
#   '또는': 1,
#   '시간제보육': 1,
#   '제공기관에': 1,
#   '근무하는': 1,
#   '보육교사': 1,
#   '및': 1,
#   '치료사,': 1,
#   '담임교사를': 1,
#   '대체하는': 1,
#   '대체교사\n': 1,
#   '평일': 1,
#   '8시간을': 1,
#   '원칙으로': 1,
#   '월': 1,
#   '15일': 1,
#   '이상': 1,
#   '근무한': 1,
#   '사람\n\n내용\n\n월': 1,
#   '11만': 1,
#   '원의': 1,
#   '특별근무수당': 1,
#   '지원\n\n방법\n\n어린이집에서': 1,
#   '매월': 1,
#   '23일부터': 1,
#   '말일까지': 1,
#   '보육통합정보시스템을': 1,
#   '통해': 1,
#   '신청\n': 1,
#   '보육통합정보시스템\n\n문의\n\n보건복지상담센터\n': 1,
#   '전화': 1,
#   '129': 1},
#  {'다문화가족': 4,
#   '방문교육': 1,
#   '서비스\n\n대상\n\n구분\n\n한국어교육': 1,
#   '\n': 14,
#   '입국': 2,
#   '5년': 2,
#   '이하': 2,
#   '결혼이민자,': 1,
#   '중도입국자녀': 1,
#   '': 9,
#   '단,': 1,
#   '이상이': 1,
#   '경과했더라도': 1,
#   '임신·출산·취업': 1,
#   '등': 1,
#   '타당한': 1,
#   '사유가': 1,
#   '있는': 2,
#   '경우': 1,
#   '지자체장과': 1,
#   '협의하에': 1,
#   '서비스': 1,
#   '지원': 1,
#   '가능': 1,
#   '중도입국': 1,
#   '자녀는': 1,
#   '외국에서': 1,
#   '성장': 1,
#   '후': 1,
#   '국내로': 1,
#   '입국한': 1,
#   '자녀로': 1,
#   '한정': 1,
#   '부모교육': 2,
#   '자녀를': 1,
#   '양육하고': 1,
#   '자녀생활서비스': 3,
#   '만': 1,
#   '312세': 1,
#   '자녀,': 1,
#   '중도입국자녀\n\n내용\n\n구분\n\n한국어교육': 1,
#   '생활언어를': 1,
#   '익히고': 1,
#   '문화를': 1,
#   '이해할': 1,
#   '수': 1,
#   '있도록': 1,
#   '한국어교육서비스': 1,
#   '제공': 3,
#   '자녀양육': 1,
#   '관련': 1,
#   '교육·정보서비스': 1,
#   '생애주기별': 1,
#   '각': 1,
#   '1회': 1,
#   '지원(임신·신생아기,': 1,
#   '유아기,': 1,
#   '아동기)': 1,
#   '학교생활': 1,
#   '및': 1,
#   '사회성': 1,
#   '발달': 1,
#   '지도': 1,
#   '지원\n\n': 1,
#   '한국어교육서비스,': 1,
#   '부모교육서비스,': 1,
#   '동시': 1,
#   '불가\n\n방법\n\n거주지': 1,
#   '읍면동': 1,
#   '주민센터(행정복지센터)에': 1,
#   '신청\n\n문의\n\n다누리콜센터(15771366)\n\n다누리': 1,
#   '누리집\n\n다누리': 1,
#   '앱': 1},
#  {'의사상자': 4,
#   '등': 3,
#   '지원\n\n대상\n\n의사자': 1,
#   '유족': 4,
#   '또는': 2,
#   '의상자와': 1,
#   '그': 2,
#   '가족\n\n내용\n\n구조행위를': 1,
#   '한': 1,
#   '당해연도의': 1,
#   '지급': 1,
#   '기준으로': 2,
#   '의사자': 2,
#   '및': 2,
#   '의상자에게': 1,
#   '보상금': 3,
#   '지급\n\n신청기간': 1,
#   '제한': 2,
#   '인정': 3,
#   '결정을': 2,
#   '통보받은': 2,
#   '날로부터': 2,
#   '3년': 2,
#   '이내\n\n의상자의': 1,
#   '경우': 1,
#   '부상': 2,
#   '등급별': 1,
#   '차등지원\n\n그': 1,
#   '외': 2,
#   '의료급여,': 1,
#   '교육보호,': 2,
#   '취업보호,': 2,
#   '국립묘지': 1,
#   '안장(이장),': 1,
#   '고궁': 1,
#   '이용료': 1,
#   '감면': 1,
#   '등을': 1,
#   '지원\n\n방법\n\n주소지': 1,
#   '구조행위': 1,
#   '발생지': 1,
#   '시군구에': 1,
#   '신청': 1,
#   '': 7,
#   '사실조사': 1,
#   '확인': 1,
#   '후': 1,
#   '인정여부': 1,
#   '청구·결정(시군구': 1,
#   '시도': 2,
#   '보건복지부)': 1,
#   '보건복지부(의사상자심사위원회)': 1,
#   '심사의결,': 1,
#   '통보(보건복지부': 1,
#   '시군구)\n\n문의\n\n시군구청': 1,
#   '사회복지': 1,
#   '관련': 1,
#   '부서\n\n보건복지상담센터': 1,
#   '129\n\n알려드립니다\n\n의사자와': 1,
#   '의상자는': 1,
#   '어떤': 1,
#   '차이가': 1,
#   '있나요\n\n의사자': 1,
#   '직무': 2,
#   '외의': 2,
#   '구조행위로': 2,
#   '사망하여': 1,
#   '의사자로': 1,
#   '인정된': 2,
#   '사람\n\n의상자': 1,
#   '부상을': 1,
#   '입어': 1,
#   '의상자로': 1,
#   '사람\n\n보상금액은': 1,
#   '얼마나': 1,
#   '되나요\n\n의사자': 1,
#   '2억': 1,
#   '2,882만': 1,
#   '3,000원(23년': 1,
#   '기준)\n\n의상자': 1,
#   '등급(19급)별로': 1,
#   '보상금의': 1,
#   '5100%': 1,
#   '지급\n\n의사상': 1,
#   '행위': 1,
#   '발생년도': 1,
#   '지급\n\n보상금': 1,
#   '지원제도는': 1,
#   '무엇이': 1,
#   '있나요\n\n의료급여,': 1,
#   '장제보호,': 1,
#   '공직진출': 1,
#   '가산점': 1,
#   '등의': 1,
#   '예우와': 1,
#   '지원': 1,
#   '실시\n\n의사자': 1,
#   '유족,': 1,
#   '의상자(16급)': 1,
#   '본인': 1,
#   '가족에': 1,
#   '대하여': 1,
#   '지원\n\n신청기간': 1,
#   '이내': 1},
#  {'사회서비스원': 1,
#   '긴급돌봄': 4,
#   '사업\n\n대상': 1,
#   '및': 4,
#   '지원대상\n\n코로나19': 1,
#   '긴급돌봄\n\n아동,': 1,
#   '노인,': 1,
#   '장애인': 1,
#   '등': 4,
#   '돌봄이': 4,
#   '필요하나,': 1,
#   '확진으로': 1,
#   '인한': 1,
#   '보호자의': 1,
#   '입원': 1,
#   '등으로': 2,
#   '가정': 1,
#   '내': 3,
#   '돌봐줄': 1,
#   '사람이': 1,
#   '부재한': 2,
#   '경우\n\n본인의': 1,
#   '자가격리': 2,
#   '코로나19': 1,
#   '확산으로': 1,
#   '이용하고': 1,
#   '있던': 1,
#   '기존': 2,
#   '돌봄서비스가': 2,
#   '중단됐으나': 1,
#   '돌봄을': 2,
#   '제공할': 2,
#   '보호자': 1,
#   '대체': 1,
#   '서비스가': 2,
#   '경우\n\n종사자': 1,
#   '확진': 1,
#   '또는': 4,
#   '백신': 1,
#   '접종': 1,
#   '후': 1,
#   '이상': 1,
#   '반응': 1,
#   '등에': 1,
#   '따른': 1,
#   '종사자': 1,
#   '휴가': 1,
#   '사회복지시설': 1,
#   '돌봄': 1,
#   '인력': 1,
#   '공백이': 1,
#   '생긴': 1,
#   '경우\n\n시·도': 1,
#   '긴급돌봄지원단': 2,
#   '대상자': 3,
#   '선정위원회에서': 2,
#   '코로나19로': 1,
#   '인해': 2,
#   '긴급하게': 2,
#   '필요하다고': 2,
#   '인정하는': 2,
#   '경우\n\n코로나19': 1,
#   '외': 2,
#   '긴급돌봄\n\n갑작스러운': 1,
#   '질병(수술)·사고,': 1,
#   '일시적': 1,
#   '신체': 1,
#   '저하로': 1,
#   '재가·이동지원': 1,
#   '필요한': 2,
#   '자\n\n일시적으로': 1,
#   '필요하나': 1,
#   '가족·부양의무자가': 1,
#   '제공하기': 1,
#   '어려운': 1,
#   '경우\n\n장애등급': 1,
#   '장기요양등급': 1,
#   '판정': 1,
#   '제도권': 1,
#   '서비스': 1,
#   '선정': 1,
#   '대기': 1,
#   '중단기적으로': 1,
#   '경우\n\n기타': 1,
#   '위기': 1,
#   '사유로': 1,
#   '긴급한': 2,
#   '시·도에서': 1,
#   '경우\n\n제공': 1,
#   '내용\n\n시도지사,': 1,
#   '시군구청장': 1,
#   '선정한': 1,
#   '대상자에게': 1,
#   '긴급돌봄서비스를': 1,
#   '수': 1,
#   '있는': 2,
#   '인력을': 1,
#   '매칭': 1,
#   '지원합니다.\n\n지원내용\n\n코로나': 1,
#   '19': 2,
#   '\n': 4,
#   '의료기관,': 1,
#   '생활치료센터': 1,
#   '입소기간,': 1,
#   '기간': 1,
#   '등을': 1,
#   '고려하여': 1,
#   '최대': 1,
#   '7일을': 1,
#   '원칙으로': 1,
#   '하되,': 1,
#   '필요가': 1,
#   '경우': 1,
#   '3일': 1,
#   '연장': 2,
#   '가능': 1,
#   '코로나': 1,
#   '일시적인': 1,
#   '위기상황': 1,
#   '1회당': 1,
#   '총': 1,
#   '100시간(30일': 1,
#   '내)': 1,
#   '지원,': 1,
#   '불가피한': 1,
#   '경우에': 1,
#   '한정하여': 1,
#   '가능\n\n신청': 1,
#   '방법\n\n시도': 1,
#   '시군구,': 1,
#   '사회서비스원에': 1,
#   '상담': 1,
#   '신청\n\n문의\n\n사회서비스원': 1,
#   '종합재가센터(대표번호': 1,
#   '15220365)': 1},
#  {'양육비': 1,
#   '이행지원': 1,
#   '종합서비스\n\n대상\n\n만': 1,
#   '19세(취학': 1,
#   '중인': 1,
#   '경우': 1,
#   '22세)': 1,
#   '미만': 1,
#   '자녀를': 1,
#   '양육하는': 1,
#   '이혼·미혼': 1,
#   '한부모·조손': 1,
#   '가족\n\n내용\n\n양육비': 1,
#   '관련': 1,
#   '상담,': 1,
#   '협의,': 1,
#   '소송': 1,
#   '및': 2,
#   '추심,': 1,
#   '이행': 1,
#   '모니터링에': 1,
#   '이르기까지': 1,
#   '맞춤형': 1,
#   '종합': 1,
#   '지원\n\n방법\n\n양육비이행관리원에': 1,
#   '신청\n': 1,
#   '양육비이행관리원': 1,
#   '누리집': 1,
#   '': 3,
#   '정보공간': 1,
#   '자료실\n\n문의\n\n양육비상담': 1,
#   '방문상담예약': 1,
#   '가족상담전화(16446621': 1,
#   '1번)\n\n온라인': 1,
#   '상담\n\n알려드립니다\n\n양육비이행관리원이란\n\n복잡한': 1,
#   '절차,': 1,
#   '많은': 1,
#   '비용': 1,
#   '등으로': 1,
#   '양육비를': 1,
#   '받지': 1,
#   '못해': 1,
#   '자녀양육에': 1,
#   '어려움을': 1,
#   '겪고': 1,
#   '있는': 1,
#   '한부모를': 1,
#   '지원하기': 1,
#   '위하여': 1,
#   '여성가족부가': 1,
#   '설립한': 1,
#   '기관입니다.': 1},
#  {'주거': 1,
#   '지원': 1,
#   '(주택': 1,
#   '특별공급)\n\n대상\n\n3년': 1,
#   '이상': 1,
#   '같은': 1,
#   '주소지에': 1,
#   '거주한': 1,
#   '무주택': 1,
#   '다문화가족\n\n내용\n\n국민주택': 1,
#   '등을': 1,
#   '특별공급\n\n방법\n\nLH에': 1,
#   '신청\n\n문의\n\nLH마이홈(16001004)': 1},
#  {'해바라기센터(성폭력': 1,
#   '피해자': 3,
#   '통합지원센터)': 1,
#   '운영\n\n대상\n\n성폭력,': 1,
#   '가정폭력,': 3,
#   '성매매': 3,
#   '피해자\n\n내용\n\n상담,': 1,
#   '의료,': 4,
#   '법률,': 4,
#   '수사': 4,
#   '지원': 6,
#   '등': 1,
#   '원스톱': 1,
#   '지원(365일': 1,
#   '24시간': 3,
#   '운영)\n': 1,
#   '폭력이': 1,
#   '초래한': 1,
#   '위기상황': 3,
#   '대처': 1,
#   '및': 9,
#   '2차': 1,
#   '피해': 1,
#   '방지': 1,
#   '목적\n\n위기지원형': 1,
#   '\n': 13,
#   '성폭력,': 2,
#   '피해자와': 3,
#   '가족(모든': 2,
#   '연령': 2,
#   '성별': 2,
#   '포함)': 2,
#   '365일': 2,
#   '대응': 2,
#   '상담,': 2,
#   '아동형': 1,
#   '성폭력': 1,
#   '가족(19세': 1,
#   '미만': 1,
#   '아동·청소년': 1,
#   '모든': 1,
#   '연령·성별': 1,
#   '지적장애인)': 1,
#   '월금': 1,
#   '9시18시': 1,
#   '상담과': 3,
#   '치료,': 3,
#   '지원,': 2,
#   '외상에': 1,
#   '대한': 1,
#   '의학적': 1,
#   '진단': 1,
#   '치료': 3,
#   '통합형': 1,
#   '후': 1,
#   '장기': 1,
#   '지원\n\n방법\n\n여성긴급전화(1366)': 1,
#   '긴급상담': 1,
#   '': 5,
#   '각': 1,
#   '지역': 1,
#   '해바라기센터': 1,
#   '서비스': 1,
#   '연계\n\n문의\n\n여성긴급전화(1366)\n\n전국': 1,
#   '해바라기센터(여성가족부': 1,
#   '누리집': 1,
#   '정책': 1,
#   '정책자료실': 1,
#   '주제별정책자료': 1,
#   '인권보호)\n\n알려드립니다\n\n성폭력': 1,
#   '피해자를': 1,
#   '위한': 2,
#   '순차적': 1,
#   '상담': 2,
#   '지원\n': 1,
#   '지원(위기·응급상담,': 1,
#   '추가·지속상담,': 1,
#   '상담교육': 1,
#   '프로그램': 1,
#   '등)\n': 3,
#   '의료': 1,
#   '지원(법의학적': 1,
#   '증거물': 1,
#   '확보,': 1,
#   '응급조치': 1,
#   '지원)\n': 2,
#   '수사·법률': 1,
#   '지원(피해자진술,': 1,
#   '지원제도': 1,
#   '활용,': 1,
#   '법률상담': 1,
#   '자문,': 1,
#   '사건': 1,
#   '심리': 2,
#   '지원(심리평가': 1,
#   '치료프로그램': 1,
#   '운영': 1,
#   '동행': 1,
#   '서비스(상담·심리·수사·법률·의료': 1,
#   '접근성': 1,
#   '확보를': 1,
#   '이동': 1,
#   '사회적': 1,
#   '지원(외부기관·외부자원': 1,
#   '연계,': 1,
#   '돌봄비': 1,
#   '등)': 1},
#  {'저임금': 1,
#   '근로자·예술인·노무제공자': 1,
#   '사회보험료': 1,
#   '지원(두루누리)\n\n대상\n\n근로자': 1,
#   '10인': 2,
#   '미만': 1,
#   '사업에서': 2,
#   '근로(종사)하는': 2,
#   '월평균보수(월보수)': 2,
#   '260만': 2,
#   '원': 4,
#   '미만인': 2,
#   '신규가입': 2,
#   '근로자,': 2,
#   '예술인,': 2,
#   '노무제공자와': 1,
#   '사업주\n근로자에': 1,
#   '한해': 1,
#   '신규가입자만': 1,
#   '지원': 3,
#   '6개월': 1,
#   '이내': 1,
#   '보험가입': 1,
#   '이력이': 1,
#   '없는': 1,
#   '근로자(상용은': 1,
#   '일용이력': 1,
#   '제외)\n\n근로자': 1,
#   '이상': 1,
#   '예술인·노무제공자\n\n내용\n\n사업주': 1,
#   '및': 2,
#   '노무제공자가': 1,
#   '부담하는': 1,
#   '사회보험료의': 1,
#   '80%': 1,
#   '지원\n\n(근로자는': 1,
#   '고용보험·국민연금': 1,
#   '지원,': 1,
#   '예술인·노무제공자는': 1,
#   '고용보험': 1,
#   '지원)\n\n방법\n\n(사업주)': 1,
#   '전월': 1,
#   '보험료': 3,
#   '완납': 1,
#   '지원신청\n\n(공단)': 1,
#   '지원대상': 1,
#   '확정\n\n다음달': 1,
#   '보험료에서': 1,
#   '지원금액을': 1,
#   '차감하고': 1,
#   '지원\n': 1,
#   '플랫폼(퀵서비스대리운전기사)': 1,
#   '종사자는': 1,
#   '신청': 1,
#   '시': 1,
#   '본인': 1,
#   '계좌로': 1,
#   '지원금': 1,
#   '이체(이용사업주플랫폼종사자': 1,
#   '각각': 1,
#   '지원신청': 1,
#   '필요)\n\n문의\n\n근로복지공단(15880075,': 1,
#   'www.comwel.or.kr)\n\n국민연금공단(1355,': 1,
#   'www.nps.or.kr)\n\n4대사회보험정보연계센터(www.4insure.or.kr)\n\n자주': 1,
#   '하는': 1,
#   '질문\n\n고액자산가': 1,
#   '기준은': 1,
#   '어떻게': 1,
#   '되나요\n\n아래': 1,
#   '항목': 1,
#   '중': 1,
#   '어느': 1,
#   '하나라도': 1,
#   '속할': 1,
#   '경우': 1,
#   '고액자산가로': 1,
#   '지원이': 1,
#   '제한됩니다.\n\n전년도': 1,
#   '재산과세표준액': 1,
#   '합계': 1,
#   '6억': 1,
#   '이상\n\n전년도(소득자료': 1,
#   '입수시기에': 1,
#   '따라': 1,
#   '보험연도의': 1,
#   '전년도': 1,
#   '또는': 1,
#   '전전년도)': 1,
#   '종합소득이': 1,
#   '연': 1,
#   '4,300만': 1,
#   '이상\n\n고용보험과': 1,
#   '국민연금에': 1,
#   '가입만': 1,
#   '되어': 1,
#   '있으면': 1,
#   '모두': 1,
#   '지원되나요\n\n그렇지': 1,
#   '않습니다.': 1,
#   '사업주의': 1,
#   '신청이': 1,
#   '있어야': 1,
#   '하며,': 1,
#   '신청일이': 1,
#   '속한': 1,
#   '월분부터': 1,
#   '지원받을': 1,
#   '수': 1,
#   '있습니다.': 1},
#  {'성폭력피해': 1,
#   '아동·청소년': 1,
#   '전용쉼터(특별지원시설)': 1,
#   '운영': 1,
#   '지원\n\n대상\n\n친족에': 1,
#   '의한': 1,
#   '성폭력': 2,
#   '피해를': 1,
#   '입은': 1,
#   '19세': 1,
#   '미만의': 1,
#   '아동·청소년\n\n내용\n\n심리·정서적': 1,
#   '지원': 6,
#   '\n': 16,
#   '개인상담,': 1,
#   '심신단련프로그램,': 1,
#   '권리찾기교육,': 1,
#   '전문심리치료기관': 1,
#   '연계': 2,
#   '등': 5,
#   '수사·법적': 1,
#   '수사의뢰,': 1,
#   '수사동행,': 1,
#   '법률상담,': 1,
#   '소송': 1,
#   '의료적': 1,
#   '치료동행,': 1,
#   '치료비': 1,
#   '지원,': 1,
#   '의료기관': 1,
#   '학교문제': 1,
#   '전학문제,': 1,
#   '지도': 1,
#   '교사면담': 1,
#   '자립': 1,
#   '취업': 1,
#   '알선,': 1,
#   '직업훈련': 1,
#   '연계,': 1,
#   '퇴소': 1,
#   '후': 2,
#   '거주지': 1,
#   '알선': 1,
#   '기타': 1,
#   '장애인': 1,
#   '등록,': 1,
#   '국가기초생활보장법': 1,
#   '수급자': 1,
#   '신청': 1,
#   '등\n\n방법\n\n성폭력상담소,': 1,
#   '통합지원센터에': 1,
#   '직접': 1,
#   '방문': 1,
#   '또는': 1,
#   '여성긴급전화(1366)를': 1,
#   '통한': 1,
#   '상담': 1,
#   '이용': 1,
#   '신청\n\n문의\n\n여성긴급전화(1366)\n\n인근': 1,
#   '피해자': 1,
#   '지원기관\n\n여성폭력': 1,
#   '사이버상담\n\n전국': 1,
#   '해바라기센터\n\n성폭력상담소': 1},
#  {'한부모가족': 1,
#   '주거': 2,
#   '지원': 1,
#   '(주택분양·임대)\n\n대상\n\n무주택': 1,
#   '저소득': 1,
#   '한부모가족\n\n내용\n\n공공임대주택': 1,
#   '지원\n\n영구임대주택,': 1,
#   '국민임대주택,': 1,
#   '행복주택,': 1,
#   '기존주택': 1,
#   '매입임대·전세임대의': 1,
#   '청약': 1,
#   '우선순위': 1,
#   '부여\n\n국민임대주택': 1,
#   '우선공급\n\n5년·10년': 1,
#   '공공임대': 1,
#   '주택은': 1,
#   '특별공급\n\n공동생활가정형(매입임대)': 1,
#   '주거지원\n\n임대보증금을': 1,
#   '국비로': 1,
#   '지원\n\n저렴한': 1,
#   '월세': 1,
#   '(14개': 1,
#   '시도': 1,
#   '운영': 1,
#   '중)\n\n서울,': 1,
#   '부산,': 1,
#   '대구,': 1,
#   '인천,': 1,
#   '광주,': 1,
#   '대전,': 1,
#   '경기,': 1,
#   '강원,': 1,
#   '충북,': 1,
#   '충남,': 1,
#   '전북,': 1,
#   '경북,': 1,
#   '경남,': 1,
#   '제주\n\n방법\n\n공공임대주택\n\nLH': 1,
#   '누리집': 1,
#   '청약센터에서': 1,
#   '공고': 1,
#   '확인': 1,
#   '후': 1,
#   '신청\n\n': 1,
#   '기관추천의': 1,
#   '경우': 1,
#   '거주지': 1,
#   '시도청': 1,
#   '여성가족과': 1,
#   '등': 1,
#   '한부모': 1,
#   '담당': 1,
#   '부서에': 1,
#   '문의\n\n공동생활가정형(매입임대)': 1,
#   '주거지원\n\n거주지': 1,
#   '읍면동': 1,
#   '주민센터(행정복지센터)': 1,
#   '또는': 1,
#   '운영기관에': 1,
#   '신청\n\n문의\n\n각종': 1,
#   '공공임대주택': 1,
#   'LH마이홈': 1,
#   '(16001004)\n\n공동생활가정형': 1,
#   '가족상담전화': 1,
#   '(16446621': 1,
#   '': 1,
#   '2번)': 1}]

# %%
bm25.idf
# Out:
# {'어르신': 4.425390849557316,
#  '국가예방접종': 4.628235458919088,
#  '지원': 0.9200572146696322,
#  '사업\n\n대상\n\n65세': 5.733341276897745,
#  '이상': 0.7666496425528715,
#  '어르신(1958년': 5.733341276897745,
#  '12월': 3.767822656454056,
#  '31일': 4.628235458919088,
#  '이전': 3.2414756567854415,
#  '출생자)\n': 5.220355825078324,
#  '주민등록상': 4.425390849557316,
#  '출생연도': 5.733341276897745,
#  '기준\n\n내용\n\n폐렴구균': 5.733341276897745,
#  '\n': 0.42791778008511994,
#  '폐렴구균': 5.220355825078324,
#  '23가': 5.733341276897745,
#  '다당': 5.733341276897745,
#  '백신(PPSV23),': 5.733341276897745,
#  '1회': 3.1836686682322743,
#  '인플루엔자': 4.881719085447539,
#  '4가': 5.220355825078324,
#  '백신(IIV),': 5.220355825078324,
#  '매년': 3.5890591188317256,
#  '': 1.3808595180326706,
#  '인플루엔자는': 5.220355825078324,
#  '접종시기가': 4.881719085447539,
#  '정해져': 4.881719085447539,
#  '있는': 1.3011086350252867,
#  '계절사업임(매년': 5.220355825078324,
#  '10월경)\n\n방법\n\n신분증을': 5.733341276897745,
#  '상시근로소득에서': 5.733341276897745,
#  '108만': 5.733341276897745,
#  '공제': 5.220355825078324,
#  '공제가': 5.733341276897745,
#  '적용됩니다.\n\n': 5.733341276897745,
#  '(22년)': 5.733341276897745,
#  '103만': 5.733341276897745,
#  '(23년)': 5.733341276897745,
#  ...}

# %%
query = str(input()) #춥고 배고파..
tokenized_query = tockenizer(query)

doc_scores = bm25.get_scores(tokenized_query)
results= bm25.get_top_n(tokenized_query, corpus1, n=3)

for i, res in enumerate(results):
    print(i+1, res)
    print('$'*20)
    print()
# Out:
# 1 한부모가족 주거 지원 (주택분양·임대)
#
# 대상
#
# 무주택 저소득 한부모가족
#
# 내용
#
# 공공임대주택 지원
#
# 영구임대주택, 국민임대주택, 행복주택, 기존주택 매입임대·전세임대의 청약 우선순위 부여
#
# 국민임대주택 우선공급
#
# 5년·10년 공공임대 주택은 특별공급
#
# 공동생활가정형(매입임대) 주거지원
#
# 임대보증금을 국비로 지원
#
# 저렴한 월세 주거 (14개 시도 운영 중)
#
# 서울, 부산, 대구, 인천, 광주, 대전, 경기, 강원, 충북, 충남, 전북, 경북, 경남, 제주
#
# 방법
#
# 공공임대주택
#
# LH 누리집 청약센터에서 공고 확인 후 신청
#
#  기관추천의 경우 거주지 시도청 여성가족과 등 한부모 담당 부서에 문의
#
# 공동생활가정형(매입임대) 주거지원
#
# 거주지 읍면동 주민센터(행정복지센터) 또는 운영기관에 신청
#
# 문의
#
# 각종 공공임대주택 LH마이홈 (16001004)
#
# 공동생활가정형 가족상담전화 (16446621  2번)
# $$$$$$$$$$$$$$$$$$$$
#
# 2 독립유공자 (손)자녀 생활지원금 (저소득가구 지원)
#
# 대상 보상금을 받지 않는 독립유공자의 (손)자녀 중 소득인정액이 기준 중위소득 70%(4인 기준 378만 675원) 이하 또는 기초연금수급자(단독 또는 부부세대)인 경우
#
# 내용 소득 수준에 따라 매월 34만 5,000원47만 8,000원까지 생활지원금 지원
#
# 방법 주소지 관할 보훈지(방)청에 신청
#
# 문의 주소지 관할 보훈지(방)청 및 보훈상담센터(15770606)
# $$$$$$$$$$$$$$$$$$$$
#
# 3 영주귀국정착금
#
# 대상 일제강점기에 국외로 망명했다가 귀국하지 못하고 해외에서 거주하다가 후에 귀국해 대한민국 국적을 취득한 독립유공자의 유족 중 세대주
#
# 유족 배우자, 자녀, 손자녀, 며느리(1945년 8월 14일 이전 구호적에 기재된 자)
#
# 내용
#
# 애국지사
#
#  1억 5,300만 원
#
#  독립유공자의 유족 중 세대주
#  정착금 지급 당시 세대주인 유족이 1명인 경우
#  7,500만 원
#
#
#  정착금 지급 당시 세대주인 유족이 2명 이상인 경우
#
#
#
#   세대주 외에 가족이 없는 경우
#  8,900만 원
#
#
#   세대주와 배우자 및 직계 가족이 23명인 경우
#  1억 2,800만 원
#
#
#   세대주와 배우자 및 직계 가족이 4명 이상인 경우
#  1억 5,300만 원
#
# 방법 수권자 관할 보훈지(방)청에 신청
#
# 문의 수권자 관할 보훈지(방)청 및 보훈상담센터(15770606)
# $$$$$$$$$$$$$$$$$$$$
